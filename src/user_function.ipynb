# %%
import pymongo
import pprint
from pprint import PrettyPrinter
import pandas as pd
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi
import os
import json
import time
from datetime import datetime
import re
import psycopg2
from bson import ObjectId

# %%
def handle_non_utf8(value):
    if isinstance(value, ObjectId):
        return str(value)
    elif isinstance(value, bool):
        return str(value)
    elif isinstance(value, (int, float)):  # Handling int and float types
        return str(value)
    elif isinstance(value, str):
        try:
            return value.encode('utf-8').decode('utf-8')
        except UnicodeDecodeError:
            return value.encode('utf-8', 'ignore').decode('utf-8')
    else:
        # For other types, you might choose to return them as they are or handle them differently
        return value

# %%
connection_string = "mongodb+srv://amrutha:root2000@cluster0.mrubvba.mongodb.net/"
client = MongoClient(connection_string)
db = client["twitter"]
c1 = db["trailtweets"]
c2 = db["trailretweets"]

# %%
# Connect to PostgreSQL
conn = psycopg2.connect(
    dbname="postgres",
    user="postgres",
    password="Call@11pm",
    host="localhost",
    port="5432"
)
cur = conn.cursor()

# %%
def time_filter(data, stime, etime, fetch_time):
    if stime==None and etime==None:
        return {'data': data, 'fetch_time': fetch_time }
    
    if stime==None:
        res = []
        etime = int(etime)/1000
        for tweet in data:
            if tweet['created_at'] <= etime:
                res.append(tweet)
        return {'data': res, 'fetch_time': fetch_time }

    if etime==None:
        res = []
        stime = int(stime)/1000
        for tweet in data:
            if tweet['created_at'] >= stime:
                res.append(tweet)
        return {'data': res, 'fetch_time': fetch_time }
    
    res = []
    stime, etime = int(stime)/1000, int(etime)/1000
    for tweet in data:
        if stime <= tweet['created_at'] <= etime:
            res.append(tweet)
    return {'data': res, 'fetch_time': fetch_time }

# %% [markdown]
# ### search_by_hashtag

# %%
def search_by_hashtag(hashtags, fromDate=None, toDate=None):
    try :
        start=time.time()
        hashtags_list = [re.escape(tag.lower()) for tag in hashtags.split('#') if tag.strip()]
        pipeline = [
            {
                "$match": {
                    "hashtags": {"$in": hashtags_list}
                }
            },
            {
                "$project": {
                    "_id": 1,
                    "retweet_count": 1,
                    "text": 1,
                    "created_at":1,
                    "user_id_str":1
                }
            },
            {
                "$sort": {"retweet_count": -1}
            }
        ]
        db_final = pd.DataFrame(list(c1.aggregate(pipeline)))
        
        # Fetch user information and add to DataFrame
        for index, row in db_final.iterrows():
            user_id = row['user_id_str']
            cur.execute(f"""SELECT screen_name FROM users1 WHERE id_str = '{user_id}'""")
            user_data = cur.fetchone()
            if user_data:
                user_info = list(user_data)
                #print("user_info: ",user_info)
                db_final.loc[index, 'screen_name'] = user_info[0]
      

        db_final_encoded = db_final.map(handle_non_utf8)
        output = json.loads(db_final_encoded.to_json(orient='records', date_format='iso'))

        end=time.time()
        time_taken = time.time() - start

        output1 = time_filter(output,fromDate,toDate,time_taken)
        return output1
    except Exception as e:
        print(f"Retrieval of Tweet from hashtags failed : {e}")

# %%
fromDate= "2020-01-01"
toDate="2020-12-31"
hashtags="#COVID2019#CORONA"
a=search_by_hashtag(hashtags)
a
# Out:
# {'data': [{'_id': '6625460bfe189a37000b8efa',
#    'created_at': '2020-03-27 17:23:16',
#    'text': 'आदरणीय प्रधानमंत्री जी ने आज रेडियो के साथियों से बात की,कैसे सब मिलकर #Corona से लड़ सकते हैं @RedFMIndia परिवार… https://t.co/CCGc6ZBCcE',
#    'retweet_count': '5983',
#    'user_id_str': '97367270'},
#   {'_id': '6625444ffe189a37000b42c7',
#    'created_at': '2020-04-11 17:38:05',
#    'text': 'मेरे पति सचिन जी का जुर्म बस इतना था कि वो #Corona महामारी के कारण #Lockdown21 में फंसे लोगों को राशन उपलब्ध करा र… https://t.co/G68yDo85vG',
#    'retweet_count': '4315',
#    'user_id_str': '1082896194731495424'},
#   {'_id': '662544f6fe189a37000b5f8d',
#    'created_at': '2020-03-27 10:05:11',
#    'text': '#Corona தொற்றால் ஏழை எளிய மக்கள் எதிர்கொண்டுள்ள மிகப்பெரிய இன்னல்களிலிருந்து அவர்களை விடுவிக்கவும், தடுப்பு நடவடிக்… https://t.co/HYjyfcIGgH',
#    'retweet_count': '1949',
#    'user_id_str': '844890761409777664'},
#   {'_id': '66254489fe189a37000b4cda',
#    'created_at': '2020-04-04 13:45:38',
#    'text': 'Those muslims who say proudly #Corona has forced everyone to wear the niqab and forced women to stop shaking hands… https://t.co/XyB0J1HRPr',
#    'retweet_count': '1037',
#    'user_id_str': '1536640243'},
#   {'_id': '662544bffe189a37000b5624',
#    'created_at': '2020-04-09 10:08:37',
#    'text': 'Or, in some western countries they have said that the #Corona patients who are #elderly, disabled &amp; have major prob… https://t.co/GsXUmA3wQt',
#    'retweet_count': '749',
#    'user_id_str': '27966935'},
#   {'_id': '66254431fe189a37000b3d2e',
#    'created_at': '2020-04-12 14:02:39',
#    'text': 'Deeply saddened to know of death due to #Corona of beloved Agniveer patron who had helped us in Mandir Nirman in Da… https://t.co/ErpBvHeWTe',
#    'retweet_count': '739',
#    'user_id_str': '1013916412325322757'},
#   {'_id': '66254514fe189a37000b652f',
#    'created_at': '2020-04-11 23:21:24',
#    'text': 'Birileri sizler için çalışıyor merak etmeyin. Sadece evde kalın!\n\n#Covid_19 #Corona #koronavirus https://t.co/bjqZeIVaqk',
#    'retweet_count': '568',
#    'user_id_str': '1212623185373327361'},
#   {'_id': '662545ecfe189a37000b89d1',
#    'created_at': '2020-04-08 04:22:26',
#    'text': '#Corona வைரஸ் நோய் தடுப்பு மற்றும் நிவாரணப் பணிகளுக்காக முதலமைச்சர் பொது நிவாரண நிதிக்கு இதுவரை பெறப்பட்ட மொத்த தொ… https://t.co/JjwNoxJ7kI',
#    'retweet_count': '559',
#    'user_id_str': '844890761409777664'},
#   {'_id': '6625452efe189a37000b69ba',
#    'created_at': '2020-04-10 11:14:30',
#    'text': 'In Tirumala 470 people isolated as 5 people test positive for #COVID2019 \n\nWaiting for @smitaprakash to book ticket… https://t.co/A0XyGaGWYI',
#    'retweet_count': '528',
#    'user_id_str': '17843247'},
#   {'_id': '6625442dfe189a37000b3c74',
#    'created_at': '2020-04-12 06:02:52',
#    'text': 'Why women leaders in Taiwan, NZ and Germany are showing how to beat #corona - because women have to be better in or… https://t.co/3xE8OkDrCc',
#    'retweet_count': '514',
#    'user_id_str': '314754247'},
#   {'_id': '66254468fe189a37000b4766',
#    'created_at': '2020-04-12 12:01:30',
#    'text': '#Kerala is steadily winning the battle vs #Corona 👍\n\nNew cases today just 2\n\nNo. of recovered today - 36 👌\n\nInspirational story indeed',
#    'retweet_count': '508',
#    'user_id_str': '221647151'},
#   {'_id': '662544bffe189a37000b5646',
#    'created_at': '2020-04-12 13:57:55',
#    'text': "Whole world is up against China today after their secrecy &amp; opacity about the #Corona virus, it's origin &amp; spread a… https://t.co/UWSFLWJ8A7",
#    'retweet_count': '481',
#    'user_id_str': '85657578'},
#   {'_id': '66254545fe189a37000b6dea',
#    'created_at': '2020-04-11 15:58:17',
#    'text': '`ஏழைகளுக்கு மளிகைப் பொருட்கள்; ஆதரவற்றோருக்கு உணவு!’ -ஊரடங்கில் பசியாற்றிய விஜய் மக்கள் இயக்கம் #Corona #vellore… https://t.co/U1H2WCo3bI',
#    'retweet_count': '477',
#    'user_id_str': '28995530'},
#   {'_id': '6625443dfe189a37000b3f49',
#    'created_at': '2020-04-09 14:45:11',
#    'text': "Shocking that even during #COVID2019, Paid trolls have been given task to spread lies about PTM. Wouldn't this mone… https://t.co/ygvZDpnc52",
#    'retweet_count': '475',
#    'user_id_str': '138340856'},
#   {'_id': '662544f3fe189a37000b5f03',
#    'created_at': '2020-04-11 20:49:48',
#    'text': 'Auch die Belgier reagieren mitunter leicht gereizt auf #Corona-Beschränkungen.\nWas denkt ihr was in #Europa (zumind… https://t.co/ANp0Zd3t2m',
#    'retweet_count': '439',
#    'user_id_str': '860808843667935232'},
#   {'_id': '662545e4fe189a37000b889a',
#    'created_at': '2020-03-15 14:13:58',
#    'text': "Mal etwas positives während der ganzen #Corona Geschichte. Da ja bald #Ostern ist, gibt's mal wieder ein kleines Ge… https://t.co/3wKb9nPWug",
#    'retweet_count': '430',
#    'user_id_str': '2732558570'},
#   {'_id': '66254429fe189a37000b3b96',
#    'created_at': '2020-04-12 12:41:15',
#    'text': '"Plazma tedavisi şu ana kadar ki en güçlü tedavi yöntemi."\n\nProf.Dr. Ercüment Ovalı\n\n#pazar #COVID2019 #Corona… https://t.co/bz4Yp9jfa7',
#    'retweet_count': '398',
#    'user_id_str': '1212623185373327361'},
#   {'_id': '662544c1fe189a37000b56a6',
#    'created_at': '2020-04-12 11:42:20',
#    'text': 'As #COVID19 patients are increasing day by day in Maharashtra,took a review of #Corona affected districts.… https://t.co/s18DADt18r',
#    'retweet_count': '346',
#    'user_id_str': '137780376'},
#   {'_id': '6625444bfe189a37000b421d',
#    'created_at': '2020-04-11 18:38:01',
#    'text': 'खुद्दार मेरे शहर का, आज भूख से मर गया.\n\nराशन तो लेना था, पर फोटो से डर गया..!\n\n#Corona  #Covid #Staysafe #karuna… https://t.co/8SLuO76Vv9',
#    'retweet_count': '331',
#    'user_id_str': '720101708'},
#   {'_id': '6625446cfe189a37000b47f9',
#    'created_at': '2020-04-12 08:56:57',
#    'text': 'डिलीवरी के 22 दिन बाद दफ्तर पहुंची कमिश्नर   \n#Coronavirus #Corona \nhttps://t.co/XeZcW1pbPE',
#    'retweet_count': '318',
#    'user_id_str': '42606652'},
#   {'_id': '66254583fe189a37000b7899',
#    'created_at': '2020-03-28 02:59:04',
#    'text': 'Day4✌✌அனேகமாக இன்னும் இரண்டு நாட்கள்ல நமக்கே பழகிடும்னு நினைக்கிறேன்😷.....\n#Corona \n#kannikaravi https://t.co/evQVU618iE',
#    'retweet_count': '302',
#    'user_id_str': '960807001189113856'},
#   {'_id': '66254581fe189a37000b7844',
#    'created_at': '2020-04-01 10:17:38',
#    'text': '#day8\nகூழ்😋😉.....\n#corona\n#kannikaravi https://t.co/oCe9l4au2G',
#    'retweet_count': '270',
#    'user_id_str': '960807001189113856'},
#   {'_id': '662545edfe189a37000b89f6',
#    'created_at': '2020-03-16 15:47:53',
#    'text': '1/ #Corona, Recession, Depression, biggest #Crash of all time...\n\nWhile everybody is occupied with speculating abou… https://t.co/kLDZogD5xB',
#    'retweet_count': '266',
#    'user_id_str': '810162381359878144'},
#   {'_id': '66254442fe189a37000b403d',
#    'created_at': '2020-04-11 12:16:38',
#    'text': 'Ahlaksız, şuursuz, idraksiz, izansız kandan beslenen pis bir güruh var!?\nOnlar istiyorlar ki #Corona herkese bulaşs… https://t.co/ESZKv4PWga',
#    'retweet_count': '232',
#    'user_id_str': '866976873762476032'},
#   {'_id': '662545cefe189a37000b850d',
#    'created_at': '2020-04-11 13:25:18',
#    'text': 'Hi @rahulkanwal, please send links to stories you have done on ruling party bigwigs flouting #corona #lockdown, or… https://t.co/3zleLvEJZ7',
#    'retweet_count': '226',
#    'user_id_str': '2458470314'},
#   {'_id': '662544affe189a37000b534b',
#    'created_at': '2020-04-12 08:16:53',
#    'text': 'Glück gehabt!\nBeim Tumult in #Belgien ging es nicht um #Corona-Beschränkungen, sondern nur um einen normalen Rache-… https://t.co/JEkpvNrInx',
#    'retweet_count': '180',
#    'user_id_str': '860808843667935232'},
#   {'_id': '662544e6fe189a37000b5cd8',
#    'created_at': '2020-04-12 12:50:56',
#    'text': 'केंद्र सरकार ने #Corona की गंभीरता को समझने में लंबा समय लगा दिया: पूर्व मुख्यमंत्री कमलनाथ\nरिपोर्ट: हेमेंद्र शर्मा… https://t.co/lHIHqqmvPX',
#    'retweet_count': '167',
#    'user_id_str': '42606652'},
#   {'_id': '662544b3fe189a37000b541d',
#    'created_at': '2020-04-12 11:27:59',
#    'text': 'پیرنی کو #Corona ہوا ہے\nاور شک #ڈرائیور پر گیا ہے\n🏃\u200d♀️🏃\u200d♀️\nیہ فنی گالہ میں چل کیا رہا ہے؟\n🙄',
#    'retweet_count': '163',
#    'user_id_str': '164876037'},
#   {'_id': '662544f7fe189a37000b5fcb',
#    'created_at': '2020-04-12 12:33:24',
#    'text': 'தொடர்ந்து உதவி செய்து வரும் கழக மகளிரணி சகோதரிகளுக்கு நன்றி!\n\n#Corona https://t.co/iV3Ja8tQv2',
#    'retweet_count': '159',
#    'user_id_str': '862799564'},
#   {'_id': '6625443efe189a37000b3f6f',
#    'created_at': '2020-04-11 13:17:08',
#    'text': 'How is it going for those people trying to make us believe #Corona is hardly worse than ordinary flu? Mortality in… https://t.co/7ONyH1MWj4',
#    'retweet_count': '150',
#    'user_id_str': '253998571'},
#   {'_id': '662544a6fe189a37000b51df',
#    'created_at': '2020-04-10 16:16:27',
#    'text': 'In the current #Corona situation, the primary need of the poor is food. Iranians are cooking food at home and distr… https://t.co/5mwSd0i6dD',
#    'retweet_count': '140',
#    'user_id_str': '1215348226087424001'},
#   {'_id': '66254609fe189a37000b8ebe',
#    'created_at': '2020-04-11 11:17:15',
#    'text': 'Waarom zou Seoul met 10 miljoen inwoners maar 2 doden hebben gehad wegens #Corona. ?\nAntwoord:  direct na de grote… https://t.co/m4NVJBOiLO',
#    'retweet_count': '132',
#    'user_id_str': '39232421'},
#   {'_id': '66254551fe189a37000b700a',
#    'created_at': '2020-04-10 15:45:48',
#    'text': 'Als kleines Dankeschön für den heldenhaften Einsatz in der #Corona-Krise hat der SPD-Arbeitsminister die Maximalarb… https://t.co/VOWt9hvHZ3',
#    'retweet_count': '126',
#    'user_id_str': '220344964'},
#   {'_id': '662544a4fe189a37000b517a',
#    'created_at': '2020-04-12 14:33:01',
#    'text': 'پاکستانیو #Corona تو ہمیں ایک دن چھوڑ ہی دے گا🙄\nلیکن #ImranKhan جیسا چور ہمیں بھوک،کرپشن،بےروزگار معیشت کی تباہی او… https://t.co/oJhoRENHkC',
#    'retweet_count': '113',
#    'user_id_str': '164876037'},
#   {'_id': '662544b8fe189a37000b54fb',
#    'created_at': '2020-04-11 12:07:34',
#    'text': 'ACZİYET NEDİR?\n\n“30 günde inşa edilen emeğin, aynı ellerle 2 saatte yıkılmasıdır.” #Corona https://t.co/nO5BeABZ69',
#    'retweet_count': '112',
#    'user_id_str': '2821820700'},
#   {'_id': '6625446efe189a37000b484d',
#    'created_at': '2020-04-09 08:30:43',
#    'text': 'Einige scheinen den Ernst von #Corona noch nicht zu verstehen: Sie wollen die #Maßnahmen einfach beenden. Lasst uns… https://t.co/Le3trrvaf6',
#    'retweet_count': '105',
#    'user_id_str': '825306344961998848'},
#   {'_id': '66254612fe189a37000b9021',
#    'created_at': '2020-04-12 09:35:38',
#    'text': 'Je länger ich mir anschaue, was im Kontext von #Corona abläuft, desto mehr sehe ich ein groß angelegtes Milgram-Exp… https://t.co/kuzwevmusu',
#    'retweet_count': '105',
#    'user_id_str': '107538567'},
#   {'_id': '66254596fe189a37000b7bc6',
#    'created_at': '2020-04-12 12:50:36',
#    'text': '#Corona entlarvt: Viele (ÖR-) Medien leiden an einem "Fehlbiss" - statt die eigene Regierung kritisieren sie umso p… https://t.co/XfYTZ6yGXw',
#    'retweet_count': '104',
#    'user_id_str': '36713389'},
#   {'_id': '662545a3fe189a37000b7e00',
#    'created_at': '2020-03-24 02:02:53',
#    'text': 'My Giveaway:\n\n♦️ https://t.co/py0x2UxnAO\n\n#Giveaway  #free #teamspeak #ts5 #Corona #push #StayAtHome #Covid_19… https://t.co/ou5IFGXI5c',
#    'retweet_count': '101',
#    'user_id_str': '877962711140839425'},
#   {'_id': '66254448fe189a37000b4172',
#    'created_at': '2020-04-12 10:11:03',
#    'text': '"Männerhorden" [BILD] verstärken in #Berlin besonders in der #corona -Zeit ihre sexuellen Übergriffe auf #Frauen! I… https://t.co/YooTX5RJkr',
#    'retweet_count': '100',
#    'user_id_str': '907354122613149697'},
#   {'_id': '66254576fe189a37000b7681',
#    'created_at': '2020-04-12 03:24:10',
#    'text': 'मॅडम आपले मुख्यमंत्री @uddhavthackeray यांनी कालच सांगितलं की #corona सारख्या विषयात #राजकारण करू नका, खोटी माहिती… https://t.co/iCU0GIJ8SG',
#    'retweet_count': '99',
#    'user_id_str': '111240477'},
#   {'_id': '662545a3fe189a37000b7de5',
#    'created_at': '2020-04-10 17:45:53',
#    'text': '🔺DIRECT INFO🔻Des jeunes sillonnent le 10e arrondissement pour donner des sandwichs et eau aux #sdf #COVID19 #Corona… https://t.co/ZbH7Y6XHXE',
#    'retweet_count': '97',
#    'user_id_str': '861904862761635840'},
#   {'_id': '66254536fe189a37000b6b26',
#    'created_at': '2020-04-09 11:43:26',
#    'text': "C'est invendable, n'a jamais servi a rien 😆\n\n#coronavirus #Macron2022 #Macron #Corona #ConfinementJour24… https://t.co/YJfyCFRbpM",
#    'retweet_count': '91',
#    'user_id_str': '1203752668910542848'},
#   {'_id': '662545a2fe189a37000b7dd5',
#    'created_at': '2020-04-12 07:44:29',
#    'text': 'Street life during #corona https://t.co/NIUTxu0z9C',
#    'retweet_count': '90',
#    'user_id_str': '721390246756282371'},
#   {'_id': '6625453cfe189a37000b6c33',
#    'created_at': '2020-04-07 11:21:41',
#    'text': 'Wegen #Corona werden unsere Grundrechte derzeit massiv eingeschränkt. @ABaerbock betont, dass diese Einschränkungen… https://t.co/QpOmYzNJBq',
#    'retweet_count': '88',
#    'user_id_str': '14553288'},
#   {'_id': '6625442efe189a37000b3c8f',
#    'created_at': '2020-04-12 10:27:33',
#    'text': '#SalmanKhan gives #Corona twist to an epic scene from his film #MainePyarKiya- watch video\n\n@BeingSalmanKhan… https://t.co/LyVrk2CQxn',
#    'retweet_count': '86',
#    'user_id_str': '4015224843'},
#   {'_id': '66254553fe189a37000b7064',
#    'created_at': '2020-04-12 13:19:20',
#    'text': '#Tiruppur #Corona #Update \nAs of 12.4.20 ,6.30 pm\nTotal people under House #Quarantine-881\n60 people are out of qua… https://t.co/l4vc12VEcb',
#    'retweet_count': '86',
#    'user_id_str': '64440095'},
#   {'_id': '6625448efe189a37000b4dd3',
#    'created_at': '2020-04-12 15:36:02',
#    'text': 'ஏழைக்கு உதவுபவன் கையைத் தட்டிவிடுகிறது: தமிழக அரசின் உத்தரவு பற்றி கமல்ஹாசன் சாடல் #CoronaVirus | #Corona | #Kamal… https://t.co/TNwuhdl5bC',
#    'retweet_count': '82',
#    'user_id_str': '1704625526'},
#   {'_id': '662544b1fe189a37000b53c2',
#    'created_at': '2020-04-11 19:22:20',
#    'text': 'Beaches in the #Netherlands  are free of people. See a deer playing in the waves. #corona has a silver lining. https://t.co/iOcF24ZUTX',
#    'retweet_count': '79',
#    'user_id_str': '1075387128396296192'},
#   {'_id': '6625444ffe189a37000b42d9',
#    'created_at': '2020-04-12 15:39:53',
#    'text': 'JUST IN\n\nDelhi Govt to implement #oddeven in times of #Corona\n\nAll wholesale mandis will now follow the #oddeven ru… https://t.co/kUJKntX9F3',
#    'retweet_count': '77',
#    'user_id_str': '2991581923'},
#   {'_id': '6625453bfe189a37000b6c0a',
#    'created_at': '2020-04-11 15:26:58',
#    'text': 'I wish all #Corona #COVIDー19 concerned and families lots of Strength Health and Love 💖\n\nMy friend Roman (29) lost t… https://t.co/iFxa6NIyhd',
#    'retweet_count': '76',
#    'user_id_str': '3622251449'},
#   {'_id': '662544a4fe189a37000b516f',
#    'created_at': '2020-04-05 22:45:39',
#    'text': 'Schaam je niet en durf te vragen! Met z’n alle komen wij hieruit! ❤️ #Corona #crisis #COVID2019 #COVID2019NL… https://t.co/m6qxyWFujK',
#    'retweet_count': '72',
#    'user_id_str': '733686846'},
#   {'_id': '6625447efe189a37000b4ae5',
#    'created_at': '2020-04-12 11:11:29',
#    'text': 'Jewish people pray in Antwerp Belgium at the windows and porches due to #Corona what left all synagogues closed https://t.co/z6JGPEBzw7',
#    'retweet_count': '68',
#    'user_id_str': '980793339573362688'},
#   {'_id': '6625448dfe189a37000b4dae',
#    'created_at': '2020-04-11 12:36:35',
#    'text': 'The Most Important thing happening to your life right now is that you are ALIVE!!! @SadhguruJV #Corona https://t.co/uFgFWCahOn',
#    'retweet_count': '68',
#    'user_id_str': '614156493'},
#   {'_id': '6625459ffe189a37000b7d3e',
#    'created_at': '2020-04-12 12:41:59',
#    'text': '#HappyEaster: @BeingSalmanKhan recreates a famous scene from #MainePyarKiya and gives a #corona twist to it.… https://t.co/QDdBNbMj5D',
#    'retweet_count': '68',
#    'user_id_str': '88147848'},
#   {'_id': '66254434fe189a37000b3d90',
#    'created_at': '2020-04-12 05:48:59',
#    'text': 'Dusting off all the virus🤪♥️  #Corona #lockdown #SocialDistancing #Quarantine https://t.co/eAq76hHziv',
#    'retweet_count': '66',
#    'user_id_str': '3259092271'},
#   {'_id': '662545b5fe189a37000b80e8',
#    'created_at': '2020-04-12 15:40:16',
#    'text': '#Corona Lockdown \nमुळे कुणी गैरफायदा घेऊन महिलांवर अत्याचार करत असेल  तर त्यांच्या विरुद्ध अतिशय कठोर कारवाई चे नि… https://t.co/mSMJekR8zf',
#    'retweet_count': '66',
#    'user_id_str': '825563486591795200'},
#   {'_id': '66254476fe189a37000b49ac',
#    'created_at': '2020-04-12 08:00:57',
#    'text': "Gov't doesn't share any information with me, I don't know how many dead, infected, ICU'd over #Corona, we can only… https://t.co/wl8cIeDBwy",
#    'retweet_count': '64',
#    'user_id_str': '823516964'},
#   {'_id': '662544cefe189a37000b58d5',
#    'created_at': '2020-04-12 12:58:52',
#    'text': '#Corona: महिला #IAS ने कैंसल की मैटरनिटी लीव, 22 दिन के बच्चे को लेकर ज्वाइन किया ऑफिस\n\n@IASassociation… https://t.co/bgMun1KHAC',
#    'retweet_count': '63',
#    'user_id_str': '801764049264332800'},
#   {'_id': '66254586fe189a37000b7935',
#    'created_at': '2020-04-11 10:20:29',
#    'text': 'Bundesregierung will trotz #Corona 2021 Millitärhaushalt um 2 Mrd. aufstocken. Das bestätigte BMVg auf Anfrage… https://t.co/whUYaBSJq6',
#    'retweet_count': '63',
#    'user_id_str': '426403057'},
#   {'_id': '662544b5fe189a37000b5479',
#    'created_at': '2020-04-12 16:47:27',
#    'text': 'உங்கள் எஜமானரின் குரலுக்காகக் காத்துக் கொண்டிருக்கிறீர்களா? - கமல் காட்டம்\n#CoronaVirus | #Corona |… https://t.co/HMjyVWNNxh',
#    'retweet_count': '58',
#    'user_id_str': '1704625526'},
#   {'_id': '662544c6fe189a37000b5766',
#    'created_at': '2020-04-12 17:25:17',
#    'text': '“... तोड़ देंगे तुम्हारे शरीर का कोना कोना \n\nपर होने नही देंगे तुमको #Corona...” \n\n~ Indian Police 🤣 🙈 \n\nजन हित में… https://t.co/S79lGZaF1H',
#    'retweet_count': '58',
#    'user_id_str': '72283791'},
#   {'_id': '662544d0fe189a37000b591b',
#    'created_at': '2020-04-12 03:49:22',
#    'text': 'Dear Barkha Ji, Chicken &amp; egg are not linked to #Corona , but the vendors are.  They might be Tablighis or those wh… https://t.co/jfAlYmmlMz',
#    'retweet_count': '58',
#    'user_id_str': '1588276453'},
#   {'_id': '662544bdfe189a37000b55c3',
#    'created_at': '2020-04-12 09:30:33',
#    'text': 'NACHDENKENSWERT❗️\n„Gerade die Deutschen gefallen sich in 150 prozentigen #Corona-Gehorsam. Nur wenn die Massnahmen… https://t.co/wm8Ii4JAv1',
#    'retweet_count': '57',
#    'user_id_str': '716634913487847425'},
#   {'_id': '6625445ffe189a37000b45d1',
#    'created_at': '2020-04-12 14:58:52',
#    'text': 'Toll, Buntbürger setzen die #Corona Maßnahmen auch an #Ostern durch.',
#    'retweet_count': '54',
#    'user_id_str': '435389605'},
#   {'_id': '6625454ffe189a37000b6fcd',
#    'created_at': '2020-04-11 06:00:00',
#    'text': '🕊 Kein #Ostermarsch für #Frieden und #Abrüstung wegen der #Corona-Krise? Nicht mit uns. Zum Glück gibt es den virtu… https://t.co/bIvMmryEjv',
#    'retweet_count': '53',
#    'user_id_str': '44101578'},
#   {'_id': '66254463fe189a37000b4688',
#    'created_at': '2020-04-11 08:10:42',
#    'text': 'तब्लीग़ी जमात का देश के खिलाफ षडियंत्र पर चंद पंक्तियाँ...\nपहले हम सिर्फ #Corona से लड़ रहे थे पर अब #CoronaZihaad… https://t.co/TZDtsG6XCK',
#    'retweet_count': '44',
#    'user_id_str': '158741397'},
#   {'_id': '6625442afe189a37000b3bcf',
#    'created_at': '2020-04-12 15:41:14',
#    'text': 'Delhi Govt to implement #oddeven in times of #Corona\n\nAll wholesale mandis will now follow the #oddeven rule\n\nStall… https://t.co/AqXb9kyyPR',
#    'retweet_count': '41',
#    'user_id_str': '158752326'},
#   {'_id': '662545eefe189a37000b8a20',
#    'created_at': '2020-04-12 14:29:11',
#    'text': '感染者週間増加数グラフ\n新型コロナウイルス\n#corona #covid19 #可視化 #東京まずい\n\n東京の感染者\u3000指数関数的な増加が止まらない\n地方に拡散しているように見える https://t.co/wWrF42SxKx',
#    'retweet_count': '41',
#    'user_id_str': '35880498'},
#   {'_id': '6625445bfe189a37000b4513',
#    'created_at': '2020-04-12 15:24:04',
#    'text': 'Şimdi polis abimiz nasıl sobelesin bu adamı? 😂😂 #corona https://t.co/qsIlrQtKGN',
#    'retweet_count': '40',
#    'user_id_str': '1095097611621728258'},
#   {'_id': '6625443bfe189a37000b3ede',
#    'created_at': '2020-04-12 10:23:00',
#    'text': 'Wir haben bereits in 193 Städten temporäre #Fahrrad-Straßen während der #Corona-Krise beantragt. Erste Erfolge gibt… https://t.co/ORPFRuX0Et',
#    'retweet_count': '37',
#    'user_id_str': '20766870'},
#   {'_id': '662544a6fe189a37000b51c3',
#    'created_at': '2020-04-12 15:34:54',
#    'text': '#oddeven in times of #Corona in #Delhi \n*All wholesale mandis will now follow the #oddeven rule\n*Stalls with odd nu… https://t.co/NCMFDGJEJU',
#    'retweet_count': '37',
#    'user_id_str': '146751977'},
#   {'_id': '6625450afe189a37000b6367',
#    'created_at': '2020-04-12 10:22:57',
#    'text': '#Corona-Clickbait bei @ntvde: Einen vorläufigen und aller Voraussicht nach vorübergehenden Zwischenstand zu einer i… https://t.co/JtXImFeIwz',
#    'retweet_count': '37',
#    'user_id_str': '14247715'},
#   {'_id': '662545a2fe189a37000b7dcb',
#    'created_at': '2020-04-09 16:31:42',
#    'text': 'Heel belangrijk: laat zorgintensieve gezinnen tijdens #Corona niet aan hun/het lot over! Geef hun zorgverleners en… https://t.co/qs2WXvEnzu',
#    'retweet_count': '37',
#    'user_id_str': '20685894'},
#   {'_id': '66254438fe189a37000b3e67',
#    'created_at': '2020-04-12 02:47:57',
#    'text': 'You want multibaggers?\nWait for stocks to fall 60-70% from their pre #Corona prices. Pick only a handful with impro… https://t.co/NIcPidXkf7',
#    'retweet_count': '35',
#    'user_id_str': '127934664'},
#   {'_id': '66254448fe189a37000b416b',
#    'created_at': '2020-04-12 12:56:02',
#    'text': 'Gibt es eigentlich genauere Infos wo sich die aktuellen neuen #Corona-Fälle in Österreich häufig anstecken?! In der… https://t.co/xiVAkWi1M5',
#    'retweet_count': '35',
#    'user_id_str': '1366981790'},
#   {'_id': '66254508fe189a37000b6316',
#    'created_at': '2020-04-11 16:54:10',
#    'text': 'Gute Zusammenfassung über das Versagen von Trump in der #Corona Krise: https://t.co/82WwqyQH8X',
#    'retweet_count': '35',
#    'user_id_str': '224343894'},
#   {'_id': '66254529fe189a37000b6904',
#    'created_at': '2020-04-11 09:29:44',
#    'text': 'Thread zu #Türkei #Corona\n\nWährend die politische Führung (=das Ein-Mann-System) für all das verantwortlich ist, wa… https://t.co/l28FD0znZ4',
#    'retweet_count': '35',
#    'user_id_str': '66106839'},
#   {'_id': '66254493fe189a37000b4eb3',
#    'created_at': '2020-04-12 14:00:59',
#    'text': 'Der Mindestabstand gilt auch für rechte Hetzer.\nLügen-#Stöckl und Anhang pöbeln rum\nund vergleichen die #Corona-Maß… https://t.co/1djUmNGSnc',
#    'retweet_count': '34',
#    'user_id_str': '964948385018019840'},
#   {'_id': '662544adfe189a37000b530c',
#    'created_at': '2020-04-12 14:40:38',
#    'text': "Birazda tebessüm 😁\nLan polis geliyor 😂😂😂\n\n#Corona \n#pazar\nAğrı Dağı\nFilistin'e\n#Polislerimizİçin21deBalkona… https://t.co/ADIalhwpAT",
#    'retweet_count': '33',
#    'user_id_str': '948222397'},
#   {'_id': '662544a4fe189a37000b5188',
#    'created_at': '2020-04-12 17:22:59',
#    'text': 'Tarihi bir an yaşıyor dünya ...\n#corona #AndreaBocelli #HappyEaster2020 https://t.co/LF5RAekJW8',
#    'retweet_count': '32',
#    'user_id_str': '322606631'},
#   {'_id': '6625444bfe189a37000b41fa',
#    'created_at': '2020-04-12 13:42:13',
#    'text': 'This I had never seen (or even imagined) before #Corona in the #Netherlands',
#    'retweet_count': '30',
#    'user_id_str': '3119735786'},
#   {'_id': '662544adfe189a37000b52f0',
#    'created_at': '2020-04-12 12:20:34',
#    'text': 'Links mag alles. Zo eenvoudig is dat eigenlijk. #UGent #Corona https://t.co/OKg4FgyOXE',
#    'retweet_count': '29',
#    'user_id_str': '2206911420'},
#   {'_id': '66254537fe189a37000b6b36',
#    'created_at': '2020-04-12 13:53:24',
#    'text': '#Corona -Regelverstöße - Die Bereitschaft zur #Denunziation ist beängstigend. Überreaktionen helfen niemandem – man… https://t.co/5Km8Ypmusu',
#    'retweet_count': '29',
#    'user_id_str': '22926365'},
#   {'_id': '66254539fe189a37000b6b9d',
#    'created_at': '2020-04-12 09:36:47',
#    'text': 'In older times, when a fort was surrounded by enemy, what was the strategy? #NBC #Corona #CoronaFreePakistan https://t.co/0zy1T5QZZ7',
#    'retweet_count': '29',
#    'user_id_str': '526250135'},
#   {'_id': '66254568fe189a37000b7427',
#    'created_at': '2020-04-12 04:57:41',
#    'text': 'Die Stichprobenstudie in #Österreich zeigt: Es sind dreimal mehr Menschen infiziert als bisher bekannt. #Corona… https://t.co/iTT5lonR4c',
#    'retweet_count': '28',
#    'user_id_str': '90524645'},
#   {'_id': '6625457dfe189a37000b77b2',
#    'created_at': '2020-04-06 12:45:58',
#    'text': 'Wir haben bei @dpa diese fantastischen Symbolbilder zu #Ostern und #Corona gefunden. Daher appellieren wir an alle… https://t.co/0sCCxYUZsr',
#    'retweet_count': '28',
#    'user_id_str': '1620250698'},
#   {'_id': '66254615fe189a37000b9096',
#    'created_at': '2020-04-12 16:49:02',
#    'text': 'Corona virüs geçtikten sonra yurdum insanı :) #COVID2019 \n #vaka56956 #EvdeKal https://t.co/gkgmnQb4Ny',
#    'retweet_count': '27',
#    'user_id_str': '901744410681106432'},
#   {'_id': '6625444ffe189a37000b42cc',
#    'created_at': '2020-04-12 13:57:13',
#    'text': 'Um die richtige Behandlung für #Corona-Patienten zu erkennen, müssten wir die #COVID19-Toten besser obduzieren, erk… https://t.co/wDsXE8kzE5',
#    'retweet_count': '26',
#    'user_id_str': '4712700575'},
#   {'_id': '662544abfe189a37000b52ad',
#    'created_at': '2020-04-12 16:03:42',
#    'text': '#Corona से लड़ने एवं कर्मचारियों को महंगायी भत्ते पर रोक लगाने वाली @ChouhanShivraj सरकार का अनोखा एवं गरीब जनता के… https://t.co/MEDTFzfODR',
#    'retweet_count': '26',
#    'user_id_str': '338209836'},
#   {'_id': '662544b8fe189a37000b54e9',
#    'created_at': '2020-04-12 12:10:51',
#    'text': 'Regardless of where you sit on the #Corvid_19 #Corona debate, we should all be very concerned about the activities… https://t.co/mpltQKIVna',
#    'retweet_count': '26',
#    'user_id_str': '990720508550373376'},
#   {'_id': '66254555fe189a37000b70c5',
#    'created_at': '2020-04-12 15:10:22',
#    'text': 'In der kommenden Woche soll darüber beraten werden, ob und welche #Corona-Maßnahmen gelockert werden. Wie ist der a… https://t.co/yu5sNfQdha',
#    'retweet_count': '26',
#    'user_id_str': '1101354170'},
#   {'_id': '66254573fe189a37000b7606',
#    'created_at': '2020-04-12 14:46:16',
#    'text': 'Güne müthiş bi haberle başladım eşimin olduğu cezaevinde doktorda #corona çıkmış.\nO hafta içerisinde revire çıkanla… https://t.co/53SpiLzBUw',
#    'retweet_count': '26',
#    'user_id_str': '1223584329365905412'},
#   {'_id': '662544befe189a37000b5619',
#    'created_at': '2020-04-11 20:48:23',
#    'text': 'Unter dem #Corona Deckmantel wird Deutschland gerade im Eiltempo zum islamischen Staat umgebaut! Ich kann gar nicht… https://t.co/otpH0LeCiN',
#    'retweet_count': '25',
#    'user_id_str': '919614735766704128'},
#   {'_id': '6625444ffe189a37000b42d3',
#    'created_at': '2020-04-12 15:36:16',
#    'text': 'Ich poste zur Abwechslung mal was aus unserem wunderschönen Land!\nEs gibt auch noch ein Leben neben #Corona!! Das V… https://t.co/CjAPS6NtoW',
#    'retweet_count': '24',
#    'user_id_str': '996497269213089793'},
#   {'_id': '662544a6fe189a37000b51e4',
#    'created_at': '2020-04-12 13:53:21',
#    'text': 'इसके प्रयोग से कोरोना भी दूर भागेगा और कोरोना फैलाने वाले भी 👌😜😬😂😂\n\n#Corona \n#ThookJihad https://t.co/1AMqTNB0qT',
#    'retweet_count': '24',
#    'user_id_str': '1161618547199447047'},
#   {'_id': '66254466fe189a37000b46ef',
#    'created_at': '2020-04-12 15:57:54',
#    'text': 'Türk Polisi yakalar...\nYakalar da işin kötüsü, beyni olmayan bu kitleye corona bile bulaşmaz...\n#corona https://t.co/FvrCE9xH6p',
#    'retweet_count': '23',
#    'user_id_str': '3007503725'},
#   {'_id': '662545dafe189a37000b86f7',
#    'created_at': '2020-04-08 20:35:15',
#    'text': 'New #Corona study: When jogging or biking, 4 - 5 meters distance are needed.  https://t.co/LxFXSFRLZD',
#    'retweet_count': '23',
#    'user_id_str': '49953488'},
#   {'_id': '662544b9fe189a37000b552d',
#    'created_at': '2020-04-12 10:16:03',
#    'text': 'More free #AAC for #corona ventilated patients/anyone with communication difficulties. Thanks to @widgit… https://t.co/l6CrUEuKRU',
#    'retweet_count': '22',
#    'user_id_str': '546285943'},
#   {'_id': '6625459bfe189a37000b7ca3',
#    'created_at': '2020-04-11 13:48:54',
#    'text': 'All My Friend Tested Negative For #Corona Virus 😍😘😘😘 https://t.co/ie2NeCZQ57',
#    'retweet_count': '22',
#    'user_id_str': '1139961066316632064'},
#   {'_id': '6625458bfe189a37000b79f4',
#    'created_at': '2020-04-12 12:17:59',
#    'text': 'In jedem seiner Auftritte verkitscht Sebastian Kurz die gesellschaftlichen Anstrengungen gegen #Corona zu so einer… https://t.co/2kPAI12KQd',
#    'retweet_count': '21',
#    'user_id_str': '101744839'},
#   {'_id': '662544e5fe189a37000b5cbe',
#    'created_at': '2020-04-12 15:06:25',
#    'text': 'Steinmeier sagte in seiner gestrigen Rede, #Corona sei eine Prüfung unserer Menschlichkeit. Dasselbe gilt für den U… https://t.co/HXw7jzrha0',
#    'retweet_count': '20',
#    'user_id_str': '1405886484'},
#   {'_id': '66254568fe189a37000b740f',
#    'created_at': '2020-03-28 00:45:19',
#    'text': 'Brian Mackey - "Keep The World Alive" - Instagram Live - YouTube #CoronaLockdown #corona #friday #StayHome… https://t.co/YGaa8xX1tF',
#    'retweet_count': '20',
#    'user_id_str': '54216369'},
#   {'_id': '662545eafe189a37000b8995',
#    'created_at': '2020-04-12 09:24:46',
#    'text': 'YENİ BİR SOKAĞA ÇIKMA YASAĞI OLUR MU?.\n#yasak #sokağacıkmaTuerkiye \n#Covid_19 #Corona #coronavirus',
#    'retweet_count': '20',
#    'user_id_str': '2693367204'},
#   {'_id': '6625449bfe189a37000b4ff9',
#    'created_at': '2020-04-12 15:12:40',
#    'text': '🔸#Corona virüsü fırsatçılığıyla;\nTorba yasa ile geçen düzenleme;\nTüm sosyal medya tek elden kontrol edilecek ve kap… https://t.co/VJ1s7xPfoy',
#    'retweet_count': '19',
#    'user_id_str': '1241991325802803200'},
#   {'_id': '662544b4fe189a37000b543a',
#    'created_at': '2020-04-12 17:19:01',
#    'text': 'आज 12 एप्रिल 2020 पर्यंतची करोना पॉझिटिव्ह रुग्णांची वॉर्डनिहाय आकडेवारी.\n#PMC #Pune #Corona https://t.co/zogLgl8wlc',
#    'retweet_count': '19',
#    'user_id_str': '3197062501'},
#   {'_id': '662544f5fe189a37000b5f73',
#    'created_at': '2020-04-11 14:38:02',
#    'text': '#HumorNegro by Becarinho #PokemonGO #QuedateEnCasa #Corona https://t.co/v1ZQ70fhl8',
#    'retweet_count': '19',
#    'user_id_str': '983356381431582720'},
#   {'_id': '662545e7fe189a37000b88f9',
#    'created_at': '2020-04-12 12:04:05',
#    'text': 'Boşuna Demedik #corona Var diye https://t.co/aee0CBNbmP',
#    'retweet_count': '19',
#    'user_id_str': '1237283677685583874'},
#   {'_id': '662544e0fe189a37000b5be7',
#    'created_at': '2020-04-11 14:47:17',
#    'text': 'Die #Polizei ist dem GG verpflichtet und nicht den #Corona Verordnungen der Regierung, die nicht einmal durchs Parl… https://t.co/aCIH0vXZNW',
#    'retweet_count': '18',
#    'user_id_str': '1169655295532044288'},
#   {'_id': '66254518fe189a37000b660a',
#    'created_at': '2020-04-12 16:20:34',
#    'text': "`சிகிச்சையின்போது மருத்துவர் மீது எச்சில் துப்பிய கொரோனா நோயாளி!' - திருச்சி அதிர்ச்சி\n#corona #Trichy\nhttps://t.co/mlLSDwbRmI",
#    'retweet_count': '18',
#    'user_id_str': '28995530'},
#   {'_id': '66254545fe189a37000b6dd5',
#    'created_at': '2020-04-12 15:01:17',
#    'text': 'Asking to follow the ‘Bhilwara Model’ directed to survey every house by forming more teams so that #corona infected… https://t.co/PGfB5WaN7i',
#    'retweet_count': '18',
#    'user_id_str': '385926583'},
#   {'_id': '662544fafe189a37000b6048',
#    'created_at': '2020-04-12 10:14:56',
#    'text': 'Exklusiv @PNN_de: Das steht im Bericht des Robert-Koch-Instituts zum #Corona-Ausbruch im #Potsdam er Klinikum https://t.co/pWBtPn4lRf',
#    'retweet_count': '17',
#    'user_id_str': '2366073302'},
#   {'_id': '6625456bfe189a37000b74b5',
#    'created_at': '2020-04-07 00:19:36',
#    'text': 'Milli Ekonomi Modeli Bağımsızlık Demektir. \n#corona #coronavirusu #covid_19 #Kovid19 #milliekonomi… https://t.co/ZMQVVa2RQQ',
#    'retweet_count': '17',
#    'user_id_str': '253146760'},
#   {'_id': '66254586fe189a37000b7913',
#    'created_at': '2020-04-12 17:08:13',
#    'text': 'Wie erlebt Ihr die #Corona-Pandemie? Nehmt an der Online-Umfrage teil und unterstützt die Forschung zur psychischen… https://t.co/IwzePi89ub',
#    'retweet_count': '17',
#    'user_id_str': '1025316884751761409'},
#   {'_id': '662545dbfe189a37000b8704',
#    'created_at': '2020-04-12 16:45:39',
#    'text': 'मध्य प्रदेश में #Corona मरीज़ों की संख्या बढ़कर 563 हुयी #Indore में 311 तो #Bhopal में 135 संक्रमित हूये..कुल मरी… https://t.co/aEEUATjyvw',
#    'retweet_count': '17',
#    'user_id_str': '734307704'},
#   {'_id': '6625445cfe189a37000b4544',
#    'created_at': '2020-04-12 09:38:11',
#    'text': 'Deutschland exportiert trotz #Corona-Pandemie weiter medizinische Schutzgüter auch in Länder außerhalb der Europäis… https://t.co/xBwL2ZfPCU',
#    'retweet_count': '16',
#    'user_id_str': '478739538'},
#   {'_id': '66254557fe189a37000b712a',
#    'created_at': '2020-04-12 15:07:57',
#    'text': 'New #corona study raises alarm!\nPollution linked to covid-19 deaths?\nWatch #Newstrack with @rahulkanwal \nLive:… https://t.co/gMugaQ23qA',
#    'retweet_count': '16',
#    'user_id_str': '19897138'},
#   {'_id': '662544a1fe189a37000b50ed',
#    'created_at': '2020-04-10 12:58:52',
#    'text': 'Shubh Number #101💓\n\n101 samples tested today for #Corona in #Uttarakhand. All are negative as per 5.00 PM report da… https://t.co/4l9GchFpvN',
#    'retweet_count': '15',
#    'user_id_str': '105837932'},
#   {'_id': '6625450efe189a37000b6433',
#    'created_at': '2020-04-12 14:40:30',
#    'text': '#ColorBlue and #colorKhakee and both on same side.\nTwo minds one thought, how to strike #Covid19  #corona and save… https://t.co/Sx9rhJ8H03',
#    'retweet_count': '14',
#    'user_id_str': '788034576719441920'},
#   {'_id': '662544bffe189a37000b564e',
#    'created_at': '2020-04-12 17:04:53',
#    'text': 'https://t.co/LhBt1GRPVe\n\nBu konser kaçmaz... \n\n#AndreaBocelli\n\n#Corona',
#    'retweet_count': '13',
#    'user_id_str': '76691248'},
#   {'_id': '66254559fe189a37000b7177',
#    'created_at': '2020-04-12 11:25:14',
#    'text': '#corona Totop vandaag zijn de #voorwaarden om #getest te worden zo #streng dat NIEMAND van de bevolking die… https://t.co/Kh7tDv9umq',
#    'retweet_count': '13',
#    'user_id_str': '866157062'},
#   {'_id': '66254478fe189a37000b4a00',
#    'created_at': '2020-04-12 16:49:41',
#    'text': 'ಗಾಂಧಿನಗರದಲ್ಲಿ #Corona ಸೋಂಕು ಹರಡದಂತೆ ಎಲ್ಲಾ ರೀತಿಯ ಮುನ್ನೆಚ್ಚರಿಕೆ ಕ್ರಮಗಳನ್ನು ಕೈಗೊಳ್ಳಲಾಗುತ್ತಿದೆ.\n\nಪ್ರತಿ ವಾರ್ಡಿನಲ್ಲಿ ಕ್ರಿ… https://t.co/B7BwYzDJuc',
#    'retweet_count': '12',
#    'user_id_str': '347102273'},
#   {'_id': '66254481fe189a37000b4b83',
#    'created_at': '2020-04-12 17:00:08',
#    'text': '#Corona -Krise in den #USA: ,Amerika lässt seine Ärmsten sterben\nhttps://t.co/I4XCDtBFVG',
#    'retweet_count': '12',
#    'user_id_str': '172884537'},
#   {'_id': '6625461bfe189a37000b91a4',
#    'created_at': '2020-04-12 12:03:35',
#    'text': 'Een idee: als we die relschoppers van #Anderlecht nu eens een maand of 12 verplicht de #Corona afdelingen in de zie… https://t.co/hthko4jfWs',
#    'retweet_count': '12',
#    'user_id_str': '14169849'},
#   {'_id': '6625446cfe189a37000b47eb',
#    'created_at': '2020-04-12 16:31:03',
#    'text': '#EMSEY Hastahanemizde #CORONA tedavisi gören hastalar sağlığına kavuşturuldu ve alkışlarla uğurlandı.! https://t.co/zM8DLMvibL',
#    'retweet_count': '11',
#    'user_id_str': '767548597269323776'},
#   {'_id': '662544adfe189a37000b52eb',
#    'created_at': '2020-04-12 16:23:44',
#    'text': 'Aangepast programma 4 en 5 mei @Comite4en5mei #Corona. Want, herdenken van oorlogsslachtoffers gaat altijd door! Op… https://t.co/QCETcgsQMS',
#    'retweet_count': '11',
#    'user_id_str': '103903623'},
#   {'_id': '662544b3fe189a37000b5407',
#    'created_at': '2020-04-12 12:22:59',
#    'text': 'न इसे इटली, स्पेन या वुहान कहते है........जहाँ मरेगा #Corona \n#virus की मौत........उसे #हिन्दुस्तान कहते है | \n\n\xa0… https://t.co/4cz71RSs0F',
#    'retweet_count': '11',
#    'user_id_str': '1021250639769358339'},
#   {'_id': '6625455bfe189a37000b71dd',
#    'created_at': '2020-04-12 08:14:42',
#    'text': 'Donated a Month worth of Food items 2 Helping Hands Humanity Orphanage in Motinagar to help them in #Corona crisis.… https://t.co/jBZ1sH8o1L',
#    'retweet_count': '11',
#    'user_id_str': '743438672658235396'},
#   {'_id': '66254529fe189a37000b68e0',
#    'created_at': '2020-04-12 08:41:48',
#    'text': '#COVID2019 #ContainmentZones ....Visited various containment zones and reviewed security and other arrangements...A… https://t.co/6tBg16Jon2',
#    'retweet_count': '11',
#    'user_id_str': '974923611789082625'},
#   {'_id': '66254448fe189a37000b4174',
#    'created_at': '2020-04-12 17:19:34',
#    'text': '#corona #Landenrangschikking op basis van het aantal #DODEN per 100.000 inwoners - #België op plaats 3. Morgen of t… https://t.co/RxLbt4i438',
#    'retweet_count': '10',
#    'user_id_str': '866157062'},
#   {'_id': '66254479fe189a37000b4a22',
#    'created_at': '2020-04-12 17:19:29',
#    'text': 'आज 12 एप्रिल 2020 पर्यंतची करोना पॉझिटिव्ह रुग्णांची वॉर्डनिहाय आकडेवारी.\n\nWard wise distribution of #Corona positi… https://t.co/tini0QC7WP',
#    'retweet_count': '10',
#    'user_id_str': '3274149036'},
#   {'_id': '6625447cfe189a37000b4a9f',
#    'created_at': '2020-04-12 05:34:56',
#    'text': 'ఓ వైపు #Corona..\n\nమరోవైపు #Lockdown.. \n\nఅయినా ఆగని ఏపీ అభివృద్ధి పనులు..👌🏻\n\nCM Jagan Sir @ysjagan 🙏🏻… https://t.co/a4xR6dFr5n',
#    'retweet_count': '10',
#    'user_id_str': '1134368965168254976'},
#   {'_id': '66254496fe189a37000b4f27',
#    'created_at': '2020-04-12 16:26:34',
#    'text': 'Coronavirus Live: बुलंदशहर में क्वारंटीन में रखे गए 16 लोग कमरे की खिड़की तोड़कर फरार #Quarantine #Corona… https://t.co/SY1QZwLdYP',
#    'retweet_count': '10',
#    'user_id_str': '1039759933728645120'},
#   {'_id': '662544defe189a37000b5ba4',
#    'created_at': '2020-04-12 13:37:45',
#    'text': 'TALE OF TWO NATIONS: While #India is saving million lives by supplying #hydrochloroquinone to cure #Corona, coward… https://t.co/gUtOoITCsZ',
#    'retweet_count': '10',
#    'user_id_str': '843837925854994432'},
#   {'_id': '6625451bfe189a37000b6691',
#    'created_at': '2020-04-12 14:00:01',
#    'text': '#PIRATEN - Rundschau 12.4.2020\nIn #Niedersachsen bekommen Polizeidienststellen die Daten von #Corona-Infizierten.\n"… https://t.co/SQxFyaqkFY',
#    'retweet_count': '10',
#    'user_id_str': '14341194'},
#   {'_id': '662545b8fe189a37000b8163',
#    'created_at': '2020-04-12 17:28:20',
#    'text': 'Jedes islamistische Regime wurde durch das @AuswaertigesAmt unter @HeikoMaas mit #Corona Schutzausrüstung reich bes… https://t.co/TtPKaeUitS',
#    'retweet_count': '10',
#    'user_id_str': '1162392142377099264'},
#   {'_id': '662545e1fe189a37000b8812',
#    'created_at': '2020-04-12 16:48:50',
#    'text': '#Telangana witnessed bit raise in #Corona new cases today\nYesterday 16\nBefore Yesterday 18\nToday 28 cases &amp; 2 death… https://t.co/sI7NEDePEA',
#    'retweet_count': '10',
#    'user_id_str': '83650063'},
#   {'_id': '662544adfe189a37000b52f5',
#    'created_at': '2020-04-02 16:19:52',
#    'text': 'Meine #Spermafresse  , ist fleissig am trainieren \nSchlucken, blasen und noch mehr...\nNach #corona wird in… https://t.co/jZcfHhmsJ2',
#    'retweet_count': '9',
#    'user_id_str': '1102331913426096130'},
#   {'_id': '6625459bfe189a37000b7c95',
#    'created_at': '2020-03-10 22:31:46',
#    'text': '#corona turkiyede https://t.co/42RjB29mph',
#    'retweet_count': '9',
#    'user_id_str': '1217237385550991360'},
#   {'_id': '662545bffe189a37000b82a7',
#    'created_at': '2020-04-12 05:45:42',
#    'text': '#JammuKashmir Youth Alliance against #Corona\n@YAAC2020 \n#youthfightscorona https://t.co/Vj4D3kXTAq',
#    'retweet_count': '9',
#    'user_id_str': '990877507812376577'},
#   {'_id': '66254449fe189a37000b41af',
#    'created_at': '2020-04-12 14:12:10',
#    'text': 'Economen en voedselvoorzienings-deskundigen voorzien hongersnoden in Afrika agv #Corona.\n\nMaar gelukkig hebben wij… https://t.co/UWylmzBpLS',
#    'retweet_count': '8',
#    'user_id_str': '86321285'},
#   {'_id': '662544c5fe189a37000b572d',
#    'created_at': '2020-04-12 17:18:32',
#    'text': '#Music is the actual medication for #corona. Hanumanji is ‘gyan gun gandharva jeta’. He will definitely bless to defeat this #pandemic',
#    'retweet_count': '8',
#    'user_id_str': '1084843905319809030'},
#   {'_id': '662544dbfe189a37000b5b00',
#    'created_at': '2020-04-12 17:25:36',
#    'text': 'Det bästa jag hört.\n\nDet var Sir Winston-klass på detta.\n\n@10DowningStreet @SwedishPM \n\n#Coronasverige #Corona',
#    'retweet_count': '8',
#    'user_id_str': '18768538'},
#   {'_id': '662544fdfe189a37000b60f3',
#    'created_at': '2020-03-11 20:55:30',
#    'text': 'Who wants to give China the big fuckyou right now? #Corona #coronavirus #IhateChina https://t.co/oSmBSQPCwA',
#    'retweet_count': '8',
#    'user_id_str': '1315452110'},
#   {'_id': '66254594fe189a37000b7b73',
#    'created_at': '2020-04-12 14:29:25',
#    'text': 'दादी तम तो बोल कै ही ठीक करदोगी\n\nखाणे की ज़रूरत ही ना पडै।😘❤️\n@realshooterdadi \n#Corona',
#    'retweet_count': '8',
#    'user_id_str': '181601889'},
#   {'_id': '66254488fe189a37000b4cd5',
#    'created_at': '2020-04-04 14:21:10',
#    'text': 'Die Menschen haben keine Mittel, um sich auf die Epidemie vorzubereiten. #Corona-Tests und Labore gibt es nicht. Nu… https://t.co/HQsL4HLkAP',
#    'retweet_count': '7',
#    'user_id_str': '996726347606130689'},
#   {'_id': '66254501fe189a37000b6195',
#    'created_at': '2020-04-12 16:57:47',
#    'text': '#BharatSamachar \n\n#Delhi : HRD मंत्रालय की पहल, #Corona से जुडी रिसर्च एक जगह मिलेगी। @DrRPNishank #Coronafighters… https://t.co/zo31jcmVrb',
#    'retweet_count': '7',
#    'user_id_str': '4453205292'},
#   {'_id': '6625452bfe189a37000b6952',
#    'created_at': '2020-03-31 07:54:34',
#    'text': 'This is what I meant when I wrote a few days back, that hunger &amp; unemployment will kill more than #Corona Virus. Un… https://t.co/IJR3I2vDwm',
#    'retweet_count': '7',
#    'user_id_str': '15374654'},
#   {'_id': '66254571fe189a37000b759f',
#    'created_at': '2020-04-11 16:16:34',
#    'text': '🖤❤️,,#Corona: #Flüchtlinge retten - Abschiebung stoppen - SOFORT!” - Jetzt unterschreiben!… https://t.co/hJSyIx4pWp',
#    'retweet_count': '7',
#    'user_id_str': '3216249275'},
#   {'_id': '66254535fe189a37000b6ae5',
#    'created_at': '2020-04-12 13:33:11',
#    'text': '1st - corona                    2nd- earthquake\n#earthquake #Corona https://t.co/g2P0KhDwgP',
#    'retweet_count': '6',
#    'user_id_str': '1138758845000327169'},
#   {'_id': '6625455efe189a37000b726d',
#    'created_at': '2020-04-06 12:35:19',
#    'text': 'Wenn irgendwer irgendwelche Behauptungen zu #Corona in sog. "Faktenchecks" prüft, brauchste nicht zu lesen! Alles,… https://t.co/N1Bids0AMt',
#    'retweet_count': '6',
#    'user_id_str': '831417031702491137'},
#   {'_id': '662545b0fe189a37000b801d',
#    'created_at': '2020-04-12 15:12:28',
#    'text': 'Biz yalnızlığı zaten seviyorduk ama #corona bunu pekiştirdi, perçinledi, üzerimize yapıştı iyice bütünleştik...… https://t.co/W1FphRPjQv',
#    'retweet_count': '6',
#    'user_id_str': '2180918480'},
#   {'_id': '6625446bfe189a37000b47e1',
#    'created_at': '2020-04-12 17:35:00',
#    'text': '#Corona #Covid_19 #NoWords ©️Hiblen https://t.co/KVavaLvw26',
#    'retweet_count': '5',
#    'user_id_str': '820174013867720704'},
#   {'_id': '6625446efe189a37000b4859',
#    'created_at': '2020-04-12 17:45:24',
#    'text': 'This is coming from a proud meat eater &amp; carnivore ... but the conversation around how this whole #corona thing mig… https://t.co/jT9xW15WUV',
#    'retweet_count': '5',
#    'user_id_str': '14526865'},
#   {'_id': '66254496fe189a37000b4f21',
#    'created_at': '2020-04-12 17:56:56',
#    'text': '@TomMayerEuropa @b_gabelle Steht wohl für 95% der Bevölkerung fest, dass strikte Maßnahmen gg. #Corona in Ordnung s… https://t.co/g6IihrtN1G',
#    'retweet_count': '5',
#    'user_id_str': '706123898019049472'},
#   {'_id': '662544c0fe189a37000b5658',
#    'created_at': '2020-04-12 16:45:28',
#    'text': 'Huge Batzooka #FederalReserve #bitcoin #btc #coronavirusmemes #Corona #stimulusbill #stimulus #Fed\n\nCredit:\nReal vi… https://t.co/oOBAYfZbF7',
#    'retweet_count': '5',
#    'user_id_str': '1065754225110585344'},
#   {'_id': '662544fefe189a37000b6114',
#    'created_at': '2020-04-12 17:33:15',
#    'text': 'Dr Lockdown से #Corona का इलाज करते-करते हम नई मुश्किल में तो नहीं फंसने जा रहे ? \n\nक्या #Lockdown की अगली पारी में… https://t.co/aBM2K99jgH',
#    'retweet_count': '5',
#    'user_id_str': '2320580942'},
#   {'_id': '66254518fe189a37000b661a',
#    'created_at': '2020-04-12 15:52:49',
#    'text': 'Together we can still change this situation with the help of #Allah almighty........\n#COVID19 @mka\n#corona… https://t.co/satdr7qfee',
#    'retweet_count': '5',
#    'user_id_str': '1165552847536046083'},
#   {'_id': '6625459cfe189a37000b7cbe',
#    'created_at': '2020-04-11 05:28:04',
#    'text': '#DUH vorgeführt: #Corona-Krise zeigt, wie sinnlos #Fahrverbote sind\n\nRead: https://t.co/D2sc2sNUDC',
#    'retweet_count': '5',
#    'user_id_str': '701797092814094336'},
#   {'_id': '662545fafe189a37000b8c33',
#    'created_at': '2020-04-12 18:13:33',
#    'text': 'Dear @MattHancock #PPE #COVID19 #Corona 🤣🤣 https://t.co/mvFAKcVE5k',
#    'retweet_count': '5',
#    'user_id_str': '229775006'},
#   {'_id': '662545fbfe189a37000b8c7a',
#    'created_at': '2020-04-12 15:50:56',
#    'text': '#Corona is killing peoples in the world \nBut for #Kashmir \nIndiaPakistan are killing kashmiris with their heavy art… https://t.co/YhRaH7L6FH',
#    'retweet_count': '5',
#    'user_id_str': '1154779642265526272'},
#   {'_id': '66254609fe189a37000b8e9b',
#    'created_at': '2020-04-12 13:45:51',
#    'text': 'Der nächste #Corona-Befreiungsschlag\n\nBundesbildungsministerin @AnjaKarliczek kündigt endlich den überfälligen Fond… https://t.co/dgh0XXjdQ8',
#    'retweet_count': '5',
#    'user_id_str': '715880857'},
#   {'_id': '66254617fe189a37000b90ed',
#    'created_at': '2020-04-12 17:00:01',
#    'text': '#PIRATEN - Rundschau 12.04.2020\nDie #Digitalisierung hat Deutschland verschlafen und jetzt - in #Corona-Zeiten muss… https://t.co/HMsJotZU1n',
#    'retweet_count': '5',
#    'user_id_str': '14341194'},
#   {'_id': '66254457fe189a37000b446b',
#    'created_at': '2020-04-06 17:12:25',
#    'text': 'My article on COVID-19 is featured on the main Coronavirus page in Medium! #coronavirus #covid19 #sarscov2 #corona https://t.co/CWmDsWHr7Z',
#    'retweet_count': '4',
#    'user_id_str': '308556599'},
#   {'_id': '662544b8fe189a37000b5504',
#    'created_at': '2020-04-12 17:45:52',
#    'text': 'Die #Verschwörungstheoretiker*innen, die den #Corona-Diskurs unterwandern wollen, haben am Samstag in größerer Zahl… https://t.co/QHamufmI1s',
#    'retweet_count': '4',
#    'user_id_str': '2778101100'},
#   {'_id': '662544befe189a37000b55fd',
#    'created_at': '2020-04-07 18:45:30',
#    'text': 'नि स्वार्थ #corona महामारी में निरंतर सेवा  करने वाले युवा मोर्चा #विदिशा जिला अध्यक्ष  भैया @BALBIRRaghuvan1 जी के… https://t.co/BATYLQSh7q',
#    'retweet_count': '4',
#    'user_id_str': '949582946993823745'},
#   {'_id': '662544e3fe189a37000b5c5c',
#    'created_at': '2020-04-12 13:42:18',
#    'text': 'Spanish press report of death of #Yanomami boy from #Corona, citing @survivalesp call to #StopBrazilsGenocide.\n\nhttps://t.co/eGpGAiNaNs',
#    'retweet_count': '4',
#    'user_id_str': '1001498767525335040'},
#   {'_id': '66254501fe189a37000b6197',
#    'created_at': '2020-04-12 17:34:57',
#    'text': 'The Lighter Side Of Life In The Middle of #Corona ! \n\nCOVID-19 AND An Earthquake? People Are Making The Funniest Me… https://t.co/CUGgF8Swmh',
#    'retweet_count': '4',
#    'user_id_str': '1863808681'},
#   {'_id': '6625452ffe189a37000b69db',
#    'created_at': '2020-04-12 16:57:45',
#    'text': 'Diabolical attempt to lift sanctions on Syria al Assad under pretext of fighting #Corona epidemic\n\nAssad &amp; Co. kill… https://t.co/xgC17qmWTV',
#    'retweet_count': '4',
#    'user_id_str': '555504754'},
#   {'_id': '66254541fe189a37000b6d15',
#    'created_at': '2020-04-10 20:39:32',
# ...
#    'text': 'Remember this too shall pass. But #wutang is #forever #corona #coronavirus https://t.co/xEb7QvRm9k',
#    'retweet_count': '0',
#    'user_id_str': '27159175'},
#   {'_id': '662545d1fe189a37000b856b',
#    'created_at': '2020-04-12 18:44:40',
#    'text': 'Die See ist wellig und eine #Romanze dauert 90Minuten . #liebe in Zeiten der #Corona https://t.co/riBNNELsVN',
#    'retweet_count': '0',
#    'user_id_str': '3393499503'},
#   {'_id': '662545d2fe189a37000b85b1',
#    'created_at': '2020-04-12 18:44:46',
#    'text': 'Great article written about indoor plumbing evolution and the possible redesign of homes after Corona. #corona.… https://t.co/kvkedYUGIi',
#    'retweet_count': '0',
#    'user_id_str': '481484530'},
#   {'_id': '662545d2fe189a37000b85b2',
#    'created_at': '2020-04-12 18:44:46',
#    'text': '#Deutschland 2020 #Corona #Merkel .... https://t.co/Fjn3yScXTV',
#    'retweet_count': '0',
#    'user_id_str': '2467933448'},
#   {'_id': '662545d4fe189a37000b85db',
#    'created_at': '2020-04-12 18:44:48',
#    'text': 'Manche Kollegen sehen einen „Virologen-Clinch“ zu #Corona, dabei ist Wissenschaftsdiskurs normal. Und in der… https://t.co/T6RwMFU6bu',
#    'retweet_count': '0',
#    'user_id_str': '17908925'},
#   {'_id': '662545d6fe189a37000b8627',
#    'created_at': '2020-04-12 18:44:51',
#    'text': '#الاردن24  #كورونا_الجديد  #كورونا  #coronavirusus #Corona     #كاريكاتير #cartoon #cartoonist #cartoons #الاردن… https://t.co/mYKfBBAv8g',
#    'retweet_count': '0',
#    'user_id_str': '1125942036'},
#   {'_id': '662545d6fe189a37000b862d',
#    'created_at': '2020-04-12 18:44:52',
#    'text': '#Corona #COVID19 (Thread)\n\nDer Palliativmediziner Matthias #Thöns: \n\nDie meisten Patienten sind hochaltrige, vielfa… https://t.co/M3SH7zRsfo',
#    'retweet_count': '0',
#    'user_id_str': '875271962'},
#   {'_id': '662545d6fe189a37000b864b',
#    'created_at': '2020-04-12 18:44:54',
#    'text': 'O zaman dans...\nHer bıjî #Corona 😂\n#SüleymanSoylu  https://t.co/C1k8oNBbYS',
#    'retweet_count': '0',
#    'user_id_str': '791593075'},
#   {'_id': '662545d6fe189a37000b8651',
#    'created_at': '2020-04-12 18:44:55',
#    'text': "🎼Oster-Power 🎷🎸: Das #corona-Spezial | Online-Orchester, ein Projekt vom Norddeutschen Film-Orchester und Rockin' S… https://t.co/2l1ZkpDJVY",
#    'retweet_count': '0',
#    'user_id_str': '1227669578660052994'},
#   {'_id': '662545d7fe189a37000b8657',
#    'created_at': '2020-04-12 18:44:55',
#    'text': 'Update status #covid19 for Spain\n#corona #data #spain',
#    'retweet_count': '0',
#    'user_id_str': '2842517351'},
#   {'_id': '662545d9fe189a37000b86a7',
#    'created_at': '2020-04-12 18:45:00',
#    'text': 'Stay in the fcukin’ hoose !!! #corona https://t.co/Mdi19ejA7x',
#    'retweet_count': '0',
#    'user_id_str': '140173955'},
#   {'_id': '662545dbfe189a37000b871b',
#    'created_at': '2020-04-12 18:45:07',
#    'text': 'حالنا بعد حجر منزلي\n#كورونا\n#حجر\n#حظر_التجول\n#tiktok\n#corona\n#stayhome https://t.co/g4HU8Advwg',
#    'retweet_count': '0',
#    'user_id_str': '1574420150'},
#   {'_id': '662545dbfe189a37000b8727',
#    'created_at': '2020-04-12 18:45:08',
#    'text': 'How many  Cuomo/Trump press conferences will there be?!?! #corona #virus #covid19 #trump #cuomo #podcast… https://t.co/3SMzwLzvQF',
#    'retweet_count': '0',
#    'user_id_str': '1227286745235906560'},
#   {'_id': '662545defe189a37000b878c',
#    'created_at': '2020-04-12 18:45:14',
#    'text': '@akhileshsharma1 तो क्या भारत को भी #Corona जैसा कोई विश्व व्यापी हथियार बनना चाहिए🤔',
#    'retweet_count': '0',
#    'user_id_str': '784391041268879360'},
#   {'_id': '662545dffe189a37000b87b8',
#    'created_at': '2020-04-12 18:45:17',
#    'text': 'استقالة وزير الداخلية التركي بعد تعرضه لانتقادات إثر إدارته لأزمة كوفيد-19 \n\n- #كورونا #Corona \n#COVID_19… https://t.co/ZjMbtQBEBf',
#    'retweet_count': '0',
#    'user_id_str': '1076931492679507971'},
#   {'_id': '662545e0fe189a37000b87d6',
#    'created_at': '2020-04-12 18:45:19',
#    'text': 'If you question how important it is to #StayHome, then listen to this nurse. #Covid_19 #corona #HealthCareHeros',
#    'retweet_count': '0',
#    'user_id_str': '632097316'},
#   {'_id': '662545e1fe189a37000b880a',
#    'created_at': '2020-04-12 18:45:22',
#    'text': 'Muss das #Traumschiff in Zeiten von #Corona denn gar nicht abgesetzt werden?',
#    'retweet_count': '0',
#    'user_id_str': '582617674'},
#   {'_id': '662545e1fe189a37000b8815',
#    'created_at': '2020-04-12 18:45:22',
#    'text': '@devianz13 Normalerweise überwiegend Industriegebiet. #Corona macht es möglich. Nicht schlecht.',
#    'retweet_count': '0',
#    'user_id_str': '2541857811'},
#   {'_id': '662545e2fe189a37000b8848',
#    'created_at': '2020-04-12 18:45:25',
#    'text': '@bercha_i Is liye aaj Faisal Vada #corona per bolay',
#    'retweet_count': '0',
#    'user_id_str': '909629781536378880'},
#   {'_id': '662545e3fe189a37000b885a',
#    'created_at': '2020-04-12 18:45:26',
#    'text': 'Update status #covid19 for Spain\n#corona #data #spain https://t.co/LkyPaqwTLN',
#    'retweet_count': '0',
#    'user_id_str': '2842517351'},
#   {'_id': '662545e5fe189a37000b88ab',
#    'created_at': '2020-04-12 18:45:31',
#    'text': '“... तोड़ देंगे तुम्हारे शरीर का कोना कोना \n\nपर होने नही देंगे तुमको #Corona...” \n\n~ Indian Police 🤣 🙈 \n\nजन हित में… https://t.co/7YUgBcpiAT',
#    'retweet_count': '0',
#    'user_id_str': '976094245202243584'},
#   {'_id': '662545e5fe189a37000b88c6',
#    'created_at': '2020-04-12 18:45:32',
#    'text': "First 'Salty' arrives in Port of Thunder Bay\n\nhttps://t.co/7MbAg82aSj\n\n#canada #canadanews #corona #canadaslondon… https://t.co/U7L1nvuXnh",
#    'retweet_count': '0',
#    'user_id_str': '1242197606379466752'},
#   {'_id': '662545e6fe189a37000b88e8',
#    'created_at': '2020-04-12 18:45:34',
#    'text': '#corona #StayHome #StayAtHome #coronavirus #Coronaturkey Reaction against measures to stop impact of #ChinaVirus in… https://t.co/fccj9oDYjN',
#    'retweet_count': '0',
#    'user_id_str': '1041659389340348416'},
#   {'_id': '662545e9fe189a37000b896f',
#    'created_at': '2020-04-12 18:45:43',
#    'text': '@HFWOdisha This happens when you try to bunk  Govt rules and show smartness. #Corona is in search of those persons… https://t.co/OVoP85q7Zx',
#    'retweet_count': '0',
#    'user_id_str': '2682165140'},
#   {'_id': '662545eafe189a37000b8993',
#    'created_at': '2020-04-12 18:45:45',
#    'text': 'let’s have a conspiracy kiki! #covid19 #covid_19 #corona #coronavirus #wuhan #china #shanedawson #deankoontz https://t.co/0jveHvRv1A',
#    'retweet_count': '0',
#    'user_id_str': '37702488'},
#   {'_id': '662545eafe189a37000b8996',
#    'created_at': '2020-04-12 18:45:45',
#    'text': 'Der türkische Innenminister Soylu tritt zurück. Hintergrund ist das Chaos vor dem kurzfristig verkündeten #Corona S… https://t.co/EVO070NEs0',
#    'retweet_count': '0',
#    'user_id_str': '2899117737'},
#   {'_id': '662545ecfe189a37000b89ee',
#    'created_at': '2020-04-12 18:45:51',
#    'text': 'Digital Master conference \n#DigitalMasterConference #GoogleClassroom #GoogleAlerts #Corona \n\nhttps://t.co/Ae81KfTVEN',
#    'retweet_count': '0',
#    'user_id_str': '3276181788'},
#   {'_id': '662545edfe189a37000b8a04',
#    'created_at': '2020-04-12 18:45:52',
#    'text': 'Update status #covid19 for France\n#corona #data #france https://t.co/TgTZB18VBs',
#    'retweet_count': '0',
#    'user_id_str': '2842517351'},
#   {'_id': '662545f0fe189a37000b8a90',
#    'created_at': '2020-04-12 18:46:00',
#    'text': 'Working on my craft and making most out of quarantine \nTag @kartikaaryan as much as u can \n#qurantine #corona… https://t.co/dKji3nOTyu',
#    'retweet_count': '0',
#    'user_id_str': '3166246719'},
#   {'_id': '662545f3fe189a37000b8b1c',
#    'created_at': '2020-04-12 18:46:08',
#    'text': 'إيطاليا تسجل 431 حالة وفاة خلال الـ24 ساعة الماضية كأقل حصيلة منذ ثلاثة أسابيع\n\n- #كورونا #Corona \n#COVID_19… https://t.co/5f0HYuOfdJ',
#    'retweet_count': '0',
#    'user_id_str': '1076931492679507971'},
#   {'_id': '662545f5fe189a37000b8b61',
#    'created_at': '2020-04-12 18:46:12',
#    'text': 'Asıl istifa etmesi gereken yerinde oturuyor...\n#Corona',
#    'retweet_count': '0',
#    'user_id_str': '85402016'},
#   {'_id': '662545f5fe189a37000b8b64',
#    'created_at': '2020-04-12 18:46:12',
#    'text': 'Nothing to do with anything #COVID19 #Corona Just a giggle after a long hard week...Keep the heads down https://t.co/kL0DxQJKA7',
#    'retweet_count': '0',
#    'user_id_str': '2391494680'},
#   {'_id': '662545f7fe189a37000b8bb6',
#    'created_at': '2020-04-12 18:46:17',
#    'text': 'Bangladeshi public during lockdown!\n\n#QuarantineLife #lockdown #Corona #COVID19 #Bangladesh\n@bbcbangla @dw_bengali… https://t.co/rMC2QT96tT',
#    'retweet_count': '0',
#    'user_id_str': '1245143925360185345'},
#   {'_id': '662545f8fe189a37000b8bd0',
#    'created_at': '2020-04-12 18:46:18',
#    'text': '#Corona के वजह से ये भी अपने अपने घरों में है। तो #भारत वासियों आप सब भी अपने अपने घरों में स्वस्थ एवं सुरक्षित रहे… https://t.co/Kbv7mF2Bz3',
#    'retweet_count': '0',
#    'user_id_str': '213965794'},
#   {'_id': '662545f8fe189a37000b8be7',
#    'created_at': '2020-04-12 18:46:20',
#    'text': 'Update status #covid19 for Turkey\n#corona #data #turkey https://t.co/B0OTbJ0j1r',
#    'retweet_count': '0',
#    'user_id_str': '2842517351'},
#   {'_id': '662545fafe189a37000b8c40',
#    'created_at': '2020-04-12 18:46:25',
#    'text': "Kerala proving again it has India's best (and most affordable) health infrastructure. Lowest death rate for #Corona… https://t.co/uJUxybvS2I",
#    'retweet_count': '0',
#    'user_id_str': '521244228'},
#   {'_id': '662545fbfe189a37000b8c70',
#    'created_at': '2020-04-12 18:46:28',
#    'text': "Hey Man I m going outside for a walk...Let me know if you need some biscuit's for you..!\n#KGV4U #Corona #COVID19… https://t.co/90jb6sEuxO",
#    'retweet_count': '0',
#    'user_id_str': '101712674'},
#   {'_id': '662545fcfe189a37000b8c82',
#    'created_at': '2020-04-12 18:46:29',
#    'text': 'Sizce durum çok vahim mi ? #soyluistifa #corona #korona #Covid_19 #EvdeKalDemesiKolay #EvdeKal #SOKAĞACIKMAYASAĞI… https://t.co/NoKc9poiHk',
#    'retweet_count': '0',
#    'user_id_str': '1139193523071344647'},
#   {'_id': '662545fdfe189a37000b8cb3',
#    'created_at': '2020-04-12 18:46:33',
#    'text': '#soyluistifa etti, #corona’nin dikkatini baska yone cekmeye calisiyorlar',
#    'retweet_count': '0',
#    'user_id_str': '417269869'},
#   {'_id': '662545fefe189a37000b8cd1',
#    'created_at': '2020-04-12 18:46:34',
#    'text': '#Corona intelligent lockdown #NL, does have some advantages, more time left spending listening to my favorite bands… https://t.co/da7a6q6mGP',
#    'retweet_count': '0',
#    'user_id_str': '278690197'},
#   {'_id': '662545fefe189a37000b8cdb',
#    'created_at': '2020-04-12 18:46:34',
#    'text': 'Sonucun bu olacağını hiç  düşünmezdim  @zekikayahan #Corona #SOKAĞACIKMAYASAĞI',
#    'retweet_count': '0',
#    'user_id_str': '241227385'},
#   {'_id': '662545fffe189a37000b8d03',
#    'created_at': '2020-04-12 18:46:37',
#    'text': '@DelhiPolice\n का तीसरा जवान कोरोना पॉजिटिव हुआ, एएसआई वीजेन्द्र सिंह की रिपोर्ट #Corona positive आई है। \n@ABPNews https://t.co/Ur5btN4GvN',
#    'retweet_count': '0',
#    'user_id_str': '806490776838369285'},
#   {'_id': '66254600fe189a37000b8d43',
#    'created_at': '2020-04-12 18:46:40',
#    'text': '#Corona-Kochstudio\n\nDer erste #Spargel der Saison kommt natürlich aus #Heinsberg.\nOhne #Erntehelfer ohne… https://t.co/S7Mpz0iDZI',
#    'retweet_count': '0',
#    'user_id_str': '1140877722916478976'},
#   {'_id': '66254602fe189a37000b8d7d',
#    'created_at': '2020-04-12 18:46:44',
#    'text': '@lawizscho @remmizs @_donalphonso Reale Zahl an Toten welche dem #corona Virus zugeordnet, im Verhältnis zur Bevölk… https://t.co/lr1xMlcEhM',
#    'retweet_count': '0',
#    'user_id_str': '1230575447144050689'},
#   {'_id': '66254602fe189a37000b8d9b',
#    'created_at': '2020-04-12 18:46:45',
#    'text': '#corona cures smAll business',
#    'retweet_count': '0',
#    'user_id_str': '1248969629227245573'},
#   {'_id': '66254604fe189a37000b8de2',
#    'created_at': '2020-04-12 18:46:50',
#    'text': '#البحرين #السعودية #كورونا #كوفيد_١٩ #عقار #قانون #افراغ \n#Bahrain #Saudi #Law #property #Real_estate #corona… https://t.co/RjMn62ZXNm',
#    'retweet_count': '0',
#    'user_id_str': '1245705309466832897'},
#   {'_id': '66254604fe189a37000b8de9',
#    'created_at': '2020-04-12 18:46:51',
#    'text': 'From Our Family to Yours!\nHe Is Risen!\n#easter #heisrisen #resurrectionday #covid #corona #quarantine @ Montana https://t.co/ux2FuAmjLM',
#    'retweet_count': '0',
#    'user_id_str': '42684496'},
#   {'_id': '66254604fe189a37000b8dec',
#    'created_at': '2020-04-12 18:46:51',
#    'text': '#Corona virus starts pushing again in Singapore, should the world worry? https://t.co/5IXPqEL0HB',
#    'retweet_count': '0',
#    'user_id_str': '1248114146547240961'},
#   {'_id': '66254608fe189a37000b8e79',
#    'created_at': '2020-04-12 18:46:59',
#    'text': '#coronavirus #corona #COVID19',
#    'retweet_count': '0',
#    'user_id_str': '2235061584'},
#   {'_id': '66254608fe189a37000b8e95',
#    'created_at': '2020-04-12 18:47:01',
#    'text': 'Die Zahl der bestätigten #Corona-Infektionen in #SachsenAnhalt ist auf 1195 Fälle gestiegen (Stand 12.12 Uhr). Nach… https://t.co/MmK8tlQV6J',
#    'retweet_count': '0',
#    'user_id_str': '1061326356'},
#   {'_id': '66254609fe189a37000b8eb1',
#    'created_at': '2020-04-12 18:47:02',
#    'text': 'kurdiya kurdên temenmezin &gt; tirkiya tirkên temenmezin. #corona pira li nav nifşan hildiweşîne, xwedî li mezinên xwe derkevin',
#    'retweet_count': '0',
#    'user_id_str': '1248026278692892675'},
#   {'_id': '6625460ffe189a37000b8fb4',
#    'created_at': '2020-04-12 18:47:19',
#    'text': 'Wear your PPE #corona https://t.co/3kY9zAyBBj',
#    'retweet_count': '0',
#    'user_id_str': '2303906162'},
#   {'_id': '66254612fe189a37000b9017',
#    'created_at': '2020-04-12 18:47:26',
#    'text': '#SueleymanSoylu #corona kaleyi içten fethetti🤪',
#    'retweet_count': '0',
#    'user_id_str': '1246169927016419333'},
#   {'_id': '66254613fe189a37000b9057',
#    'created_at': '2020-04-12 18:47:29',
#    'text': '#corona-compliant varieties of political #protest: the "political queue" in #Potsdam #SocialDistancing… https://t.co/6DNGTZP11w',
#    'retweet_count': '0',
#    'user_id_str': '826449810492362756'},
#   {'_id': '66254616fe189a37000b90c3',
#    'created_at': '2020-04-12 18:47:35',
#    'text': "Birazdan Yayındayız 22:15 'te malum kanal da 😉\n#rulet #Roulette #games #Covid_19 #StayHome #EvdeKal #Corona… https://t.co/NacIisIMh7",
#    'retweet_count': '0',
#    'user_id_str': '1236061526706065408'},
#   {'_id': '66254616fe189a37000b90df',
#    'created_at': '2020-04-12 18:47:37',
#    'text': '#Corona पर हँस लो न 😂 https://t.co/atey4UJLrW',
#    'retweet_count': '0',
#    'user_id_str': '2784430537'},
#   {'_id': '6625461cfe189a37000b91b6',
#    'created_at': '2020-04-12 18:47:50',
#    'text': 'दुनिया ऐसी उल्टी घूमी कि पॉजिटिव ही सबसे निगेटिव शब्द बन गया है\n#Corona',
#    'retweet_count': '0',
#    'user_id_str': '75812120'},
#   {'_id': '6625453bfe189a37000b6c1e',
#    'created_at': '2020-04-12 18:38:26',
#    'text': 'A public service massage from these guys for corona awareness.\n#StayAtHome\n#COVID2019 https://t.co/uHyhGgXEpV',
#    'retweet_count': '0',
#    'user_id_str': '563839956'},
#   {'_id': '66254571fe189a37000b75a4',
#    'created_at': '2020-04-12 18:40:44',
#    'text': 'When America become the No1 country in the world but in the number of Corona virus cases #COVID2019 https://t.co/eY8msDFVWr',
#    'retweet_count': '0',
#    'user_id_str': '3221957214'},
#   {'_id': '662545bffe189a37000b82aa',
#    'created_at': '2020-04-12 18:43:57',
#    'text': 'Feeling inadequate knowing I’ll probably never create a funny COVID meme #COVID19 #Covid_19 #COVID2019 #COVID19ON… https://t.co/fSRDiZYBn9',
#    'retweet_count': '0',
#    'user_id_str': '1238188103376011264'},
#   {'_id': '66254604fe189a37000b8dda',
#    'created_at': '2020-04-12 18:46:50',
#    'text': '#COVID2019 Der türkische Innenminister Soylu tritt zurück. Hintergrund ist das Chaos vor dem kurzfristig verkündete… https://t.co/cOqyCa2mVs',
#    'retweet_count': '0',
#    'user_id_str': '964076392177700864'}],
#  'fetch_time': 0.5407600402832031}

# %% [markdown]
# ### search_by_user

# %%
def search_by_user(user_id=None,fromDate=None,toDate=None):

    try:
        if user_id:
            start=time.time()
            pipeline = [
                {
                    "$match": {
                        "user_id_str":user_id
                    }
                },
                {
                    "$project": {
                        "_id":0,
                        "id_str": 1,
                        "retweet_count": 1,
                        "text": 1,
                        'created_at':1
                    }
                },
            ]
            db_final1 = pd.DataFrame(list(c1.aggregate(pipeline)))
            db_final2 = pd.DataFrame(list(c2.aggregate(pipeline)))
            merged_df = pd.concat([db_final1, db_final2], ignore_index=True)
            cur.execute(f"""SELECT screen_name FROM user_data WHERE id_str = '{user_id}'""")
            user_data = cur.fetchone()
            user_info = list(user_data)
            merged_df['screen_name']=user_info[0]
            #print(merged_df)
            db_final_encoded = merged_df.map(handle_non_utf8)
            # Convert the DataFrame to JSON
            output = json.loads(db_final_encoded.to_json(orient='records', date_format='iso'))

            end=time.time()
            time_taken = time.time() - start

            output1 = time_filter(output,fromDate,toDate,time_taken)
            return output1

    except Exception as e:
        print(f"Retrieval of Tweet from hashtags failed : {e}")

# %%
user_id="1131227186"
a=search_by_user(user_id)
a
# Out:
# {'data': [{'created_at': '2020-03-10 17:52:14',
#    'id_str': '1237436114887041024',
#    'text': 'THIS MAN IS A GENIUS he figured out the Corona virus problem 😮 https://t.co/EZP7IqTtxV',
#    'retweet_count': '179479',
#    'screen_name': '_AyeeCarlos_'}],
#  'fetch_time': 0.057047128677368164}

# %% [markdown]
# ### search_by_tweet

# %%
def search_by_tweet(tweet_str=None, fromDate=None, toDate=None):
    try:
        if tweet_str:
            start= time.time()
            pipeline = [
                {
                    "$match": {
                        "$text": {"$search": tweet_str}
                    }
                },
                {
                    "$project": {
                        "id_str":1,
                        "relevance_score": {"$meta": "textScore"}, 
                        "text": 1, 
                        "retweet_count":1,
                        "user_id_str": 1,
                        "created_at":1,
                        "favorite_count":1
                    }
                }
            ]
            db_final = pd.DataFrame(list(c1.aggregate(pipeline,allowDiskUse=True)))
            
            # Fetch user information and add to DataFrame
            for index, row in db_final.iterrows():
                user_id = row['user_id_str']
                cur.execute(f"""SELECT screen_name FROM users1 WHERE id_str = '{user_id}'""")
                user_data = cur.fetchone()
                if user_data:
                    user_info = list(user_data)
                    #print("user_info: ",user_info)
                    db_final.loc[index, 'screen_name'] = user_info[0]
            # Drop unnecessary columns
            db_final = db_final.drop(['_id'], axis=1).sort_values(by='relevance_score',ascending=False)
            
             # Apply the function to the DataFrame
            db_final_encoded = db_final.map(handle_non_utf8)
            # Convert the DataFrame to JSON
            output = json.loads(db_final_encoded.to_json(orient='records', date_format='iso'))
            
            end=time.time()
            time_taken = time.time() - start
            output1 = time_filter(output,fromDate,toDate,time_taken)
            return output1

    except Exception as e:
        print(f"Retrieval of Tweet from hashtags failed : {e}")

# %%
fromDate= "2020-01-01"
toDate="2020-12-31"
tweet_str="corona"
a=search_by_tweet(tweet_str)
a
# Out:
# {'data': [{'created_at': '2020-04-12 18:32:19',
#    'id_str': '1249405001346187264',
#    'text': '@simplicio10 CORONA CORONA CORONA CORONA',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '457944387',
#    'relevance_score': '1.6875'},
#   {'created_at': '2020-04-12 18:39:30',
#    'id_str': '1249406807652655108',
#    'text': 'corona virus corona virus corona-So I misspelled corona and many other words.  I haven\'t misspelled this, "Halo cor… https://t.co/461k6jeyfY',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '752240689',
#    'relevance_score': '1.171875'},
#   {'created_at': '2020-04-12 14:20:14',
#    'id_str': '1249341560514174976',
#    'text': 'corona oh corona wkwkw',
#    'retweet_count': '1',
#    'favorite_count': '0',
#    'user_id_str': '1248098315620610053',
#    'relevance_score': '1.125'},
#   {'created_at': '2020-04-12 18:37:54',
#    'id_str': '1249406404013764608',
#    'text': 'Corona',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '1248439943384440839',
#    'relevance_score': '1.1'},
#   {'created_at': '2020-04-12 18:33:06',
#    'id_str': '1249405199153803265',
#    'text': 'can’t wait for all the corona fashion spreads post corona. or just fashion corona things in general. lol.',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '34728596',
#    'relevance_score': '1.0625'},
#   {'created_at': '2020-04-12 18:33:13',
#    'id_str': '1249405224801808384',
#    'text': 'Puri Duniya yahan CORONA Se pareshan hai...!!\n\n              Aur... Hum ..!!!\n\nCORONA ki callertune Se !!\n\n#Corona',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '1131508328608161792',
#    'relevance_score': '1.0625'},
#   {'created_at': '2020-04-12 18:47:06',
#    'id_str': '1249408719433031683',
#    'text': 'Big Corona Warrior 💪 https://t.co/nz5BnCFZVO corona deletes others, she is deleting corona. https://t.co/QJSqm83n8g',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '1249406247209553920',
#    'relevance_score': '1.0294117647058825'},
#   {'created_at': '2020-04-12 13:11:17',
#    'id_str': '1249324207315521536',
#    'text': "Corona ile CHP' nin karşılaştırılması...\n\nCorona hücre içinde, CHP toplum içinde yaşar.\nCorona insanın ciğerini , C… https://t.co/BYhcKY1gFX",
#    'retweet_count': '65',
#    'favorite_count': '399',
#    'user_id_str': '1105452409256636417',
#    'relevance_score': '1.0062499999999999'},
#   {'created_at': '2020-04-12 18:40:29',
#    'id_str': '1249407055921909761',
#    'text': 'Oy corona corona çıktın hükümet avına',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '947008563825737729',
#    'relevance_score': '1.0'},
#   {'created_at': '2020-04-12 18:45:18',
#    'id_str': '1249408267891044355',
#    'text': '@ corona',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '1229999178',
#    'relevance_score': '1.0'},
#   {'created_at': '2020-03-21 16:49:31',
#    'id_str': '1241406598515494912',
#    'text': 'Corona :',
#    'retweet_count': '80',
#    'favorite_count': '299',
#    'user_id_str': '1016895818450849792',
#    'relevance_score': '1.0'},
#   {'created_at': '2020-04-10 23:54:40',
#    'id_str': '1248761347623526406',
#    'text': 'May Corona virus end before ramadan\nMay Corona virus end before ramadan\nMay Corona virus end before ramadan\nMay Cor… https://t.co/Ff0mFM9aIc',
#    'retweet_count': '426',
#    'favorite_count': '1185',
#    'user_id_str': '1436906713',
#    'relevance_score': '1.0'},
#   {'created_at': '2020-03-30 17:00:46',
#    'id_str': '1244670919521509377',
#    'text': '#30Mar QUITALE LA CORONA AL VIRUS. LÁVATE LAS MANOS FRECUENTEMENTE! La corona del Corona Virus es la llave que él U… https://t.co/oMqwV6xc4E',
#    'retweet_count': '13',
#    'favorite_count': '4',
#    'user_id_str': '2264970750',
#    'relevance_score': '0.9800000000000001'},
#   {'created_at': '2020-04-12 18:27:52',
#    'id_str': '1249403878304432128',
#    'text': '@PhotoChhoree Go corona go, go corona go.',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '1205158606703718400',
#    'relevance_score': '0.9642857142857142'},
#   {'created_at': '2020-04-12 13:38:10',
#    'id_str': '1249330974111854594',
#    'text': 'Corona-chan has me.\n\nPress S to spit on Corona-chan.',
#    'retweet_count': '2',
#    'favorite_count': '43',
#    'user_id_str': '931750129614274560',
#    'relevance_score': '0.9642857142857142'},
#   {'created_at': '2020-04-12 18:22:10',
#    'id_str': '1249402447296069634',
#    'text': '@casspernyovest After school is after... Scratch that!\n\nAfter Corona is after corona @akaworldwide 😂',
#    'retweet_count': '2',
#    'favorite_count': '8',
#    'user_id_str': '2171797930',
#    'relevance_score': '0.9642857142857142'},
#   {'created_at': '2020-04-12 17:47:34',
#    'id_str': '1249393739086229504',
#    'text': 'corona paved the way pls.\nsemua online karena corona.',
#    'retweet_count': '5',
#    'favorite_count': '10',
#    'user_id_str': '1140570352872906754',
#    'relevance_score': '0.9375'},
#   {'created_at': '2020-04-12 18:37:03',
#    'id_str': '1249406190704099328',
#    'text': '@sahraslan34 ➰Sen hiç duymadınmı Corona varrr corona corona😂🤗🤗',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '1216034267534364672',
#    'relevance_score': '0.9375'},
#   {'created_at': '2020-04-12 18:33:24',
#    'id_str': '1249405271140478976',
#    'text': '@ipanhakimm @corona banyak agenda bisa disusun habis corona',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '1000488928024055808',
#    'relevance_score': '0.9375'},
#   {'created_at': '2020-04-12 13:33:11',
#    'id_str': '1249329720254238721',
#    'text': '1st - corona                    2nd- earthquake\n#earthquake #Corona https://t.co/g2P0KhDwgP',
#    'retweet_count': '6',
#    'favorite_count': '10',
#    'user_id_str': '1138758845000327169',
#    'relevance_score': '0.8999999999999999'},
#   {'created_at': '2020-04-12 18:40:21',
#    'id_str': '1249407021721452545',
#    'text': '@barisatay Muhalefetin yapamadığını corona yaptı benim Cumhurbaşkanı adayım CORONA 😀',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '203516380',
#    'relevance_score': '0.8999999999999999'},
#   {'created_at': '2020-04-12 13:54:13',
#    'id_str': '1249335014543822848',
#    'text': '2k15                               2k20\nsem corona                 com corona https://t.co/4CWjhDKAsX',
#    'retweet_count': '34',
#    'favorite_count': '89',
#    'user_id_str': '888111867226341376',
#    'relevance_score': '0.8999999999999999'},
#   {'created_at': '2020-04-12 18:32:03',
#    'id_str': '1249404934564376577',
#    'text': '@khemka_mk corona kootwayenge tumse ,, corona powder khatam ho gaya...😂😂🤘',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '1213088338086772736',
#    'relevance_score': '0.8999999999999999'},
#   {'created_at': '2020-04-12 18:40:42',
#    'id_str': '1249407109227257858',
#    'text': '@gozdeakpinar Muhalefetin yapamadığını corona yaptı benim Cumhurbaşkanı adayım CORONA 😀',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '203516380',
#    'relevance_score': '0.8999999999999999'},
#   {'created_at': '2020-04-12 18:33:10',
#    'id_str': '1249405213955538944',
#    'text': "Playing the thick card here: what's the difference between dying 'with' Corona, and dying 'of' Corona?",
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '573735854',
#    'relevance_score': '0.8999999999999999'},
#   {'created_at': '2020-04-12 18:47:16',
#    'id_str': '1249408762898677767',
#    'text': '@mhulkicevizoglu Muhalefetin yapamadığını corona yaptı benim Cumhurbaşkanı adayım CORONA 😀',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '203516380',
#    'relevance_score': '0.8999999999999999'},
#   {'created_at': '2020-04-12 12:40:26',
#    'id_str': '1249316444686483456',
#    'text': 'Oy corona corona tey teeyy teeyy 🙂 https://t.co/7EANulvYFk',
#    'retweet_count': '12',
#    'favorite_count': '65',
#    'user_id_str': '1124599680657178624',
#    'relevance_score': '0.8863636363636365'},
#   {'created_at': '2020-04-12 09:49:51',
#    'id_str': '1249273515288793088',
#    'text': "Corona or no Corona, I'm completing this year successfully. I WILL GRADUATE!!! https://t.co/Yiv5rLDbtj",
#    'retweet_count': '218',
#    'favorite_count': '968',
#    'user_id_str': '340959711',
#    'relevance_score': '0.8863636363636365'},
#   {'created_at': '2020-04-12 14:22:32',
#    'id_str': '1249342139663876097',
#    'text': 'corona served with cancelling church my mom can’t threaten me omg CORONA WE LAUV YOU!!!!',
#    'retweet_count': '8',
#    'favorite_count': '127',
#    'user_id_str': '2871979310',
#    'relevance_score': '0.8863636363636365'},
#   {'created_at': '2020-04-11 16:35:11',
#    'id_str': '1249013133718343685',
#    'text': 'Boycott All Single Sources.\nBe Corona free.\nBe Happy. \n\nBoycott All Thookers.\nBe Corona Free. \nBe Happy.',
#    'retweet_count': '188',
#    'favorite_count': '379',
#    'user_id_str': '990185512798433280',
#    'relevance_score': '0.8863636363636365'},
#   {'created_at': '2020-04-12 12:21:38',
#    'id_str': '1249311715944169472',
#    'text': 'Jo bre se nuk vjen Corona nPrishtine\n\nCorona: https://t.co/Upbge5rPKu',
#    'retweet_count': '5',
#    'favorite_count': '26',
#    'user_id_str': '2641725767',
#    'relevance_score': '0.875'},
#   {'created_at': '2020-04-12 18:35:20',
#    'id_str': '1249405759093424128',
#    'text': '@davialcolumbre Vejo q vc se curou do Corona vírus q pena do Corona vírus .',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '2713386333',
#    'relevance_score': '0.875'},
#   {'created_at': '2020-04-12 18:33:18',
#    'id_str': '1249405248696799233',
#    'text': 'berreyi corona olmadığına ikna etmeye çalışıyorum. sen corona değilsin sadece delisin berre.',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '1023559163622903808',
#    'relevance_score': '0.875'},
#   {'created_at': '2020-04-12 18:42:01',
#    'id_str': '1249407439830687746',
#    'text': 'There’s been talk of a few deaths in littlehey prison due to corona- sex offender prison!  Bring on the corona',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '1239979892915273729',
#    'relevance_score': '0.875'},
#   {'created_at': '2020-04-12 18:32:41',
#    'id_str': '1249405093448826880',
#    'text': 'Me:kal se pakka study krungi Corona ki kasam\n\n*Corona* https://t.co/xh5ongqRPq',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '1219196253956763649',
#    'relevance_score': '0.8653846153846153'},
#   {'created_at': '2020-04-12 16:09:26',
#    'id_str': '1249369041350901760',
#    'text': "#چور_دےپتر_پٹواری Shahbaz Sharif says I can finish corona in a week. Tell him that this is corona. not Pakistan's national treasure!",
#    'retweet_count': '19',
#    'favorite_count': '1',
#    'user_id_str': '3300853952',
#    'relevance_score': '0.8653846153846153'},
#   {'created_at': '2020-04-12 12:59:49',
#    'id_str': '1249321325681917952',
#    'text': 'Fit-bleiben-während-Corona-Oster-Edition. #Corona #Easter #StayHome https://t.co/EcHMxumsdR',
#    'retweet_count': '1',
#    'favorite_count': '1',
#    'user_id_str': '759421090200518657',
#    'relevance_score': '0.8653846153846153'},
#   {'created_at': '2020-04-12 18:27:43',
#    'id_str': '1249403841235296256',
#    'text': 'Will they blame corona virus on immigrants and sex workers when they’re corona virus free?? Find out next.',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '258970579',
#    'relevance_score': '0.8653846153846153'},
#   {'created_at': '2020-04-12 18:43:07',
#    'id_str': '1249407717283901440',
#    'text': 'Corona in Latin means “crown”... so the corona-virus is a QUEEN??? Period, no wonder it’s Miss Rona 💅🏻',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '2345546113',
#    'relevance_score': '0.8653846153846153'},
#   {'created_at': '2020-04-12 18:15:01',
#    'id_str': '1249400647574867969',
#    'text': "@_corpreneur Save up for post Corona enjoyments...don't miss out on all the flex after Corona\n#SaveWithCorpreneur… https://t.co/aOStBLRV9X",
#    'retweet_count': '1',
#    'favorite_count': '1',
#    'user_id_str': '868909951758028800',
#    'relevance_score': '0.8653846153846153'},
#   {'created_at': '2020-04-12 18:33:54',
#    'id_str': '1249405399834537984',
#    'text': '@Sevgi_ysr We have been saying that it has been corona virus for a month.  Authorities say there is no Corona.\nTwo… https://t.co/B3o9drCTFg',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '944146496',
#    'relevance_score': '0.8653846153846153'},
#   {'created_at': '2020-04-12 18:34:33',
#    'id_str': '1249405561503965192',
#    'text': 'The devil in America is saying to  infected with Corona virus in America , " we could gas you, we could corona you,… https://t.co/hRrnapxdhK',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '1004632708453163008',
#    'relevance_score': '0.8653846153846153'},
#   {'created_at': '2020-04-12 17:50:45',
#    'id_str': '1249394538323591176',
#    'text': 'CDC update: you can catch corona virus by turning the lights out in the bathroom and saying “corona” 3 times.',
#    'retweet_count': '2',
#    'favorite_count': '2',
#    'user_id_str': '1149381875372367872',
#    'relevance_score': '0.8653846153846153'},
#   {'created_at': '2020-04-12 18:35:11',
#    'id_str': '1249405721139175424',
#    'text': '@Prakash12441483 When the corona was confirmed on January 30, then no corona-infected person would have reached the… https://t.co/l4VpW6k9qd',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '2666987689',
#    'relevance_score': '0.8653846153846153'},
#   {'created_at': '2020-04-12 18:36:03',
#    'id_str': '1249405938529898505',
#    'text': 'The devil in America is saying to the infected with Corona virus in America," we could gas you, we could corona you… https://t.co/rsepB3WvIC',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '1004632708453163008',
#    'relevance_score': '0.8653846153846153'},
#   {'created_at': '2020-04-12 18:29:40',
#    'id_str': '1249404332728033280',
#    'text': 'tomando uma corona e pensando no quanto o corona ta avacalhando com a situation kkkkkkk',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '978081579494002688',
#    'relevance_score': '0.8653846153846153'},
#   {'created_at': '2020-04-12 18:47:09',
#    'id_str': '1249408733597360129',
#    'text': '@StunnaMPB Utak yi leswi vari corona hito hiyo corona 😂😂😂 https://t.co/H8s938Jtcn',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '264716628',
#    'relevance_score': '0.8571428571428571'},
#   {'created_at': '2020-04-12 18:30:14',
#    'id_str': '1249404477590745088',
#    'text': '@CMOGuj @vijayrupanibjp What is our preparation to spread corona? Are maximum testing of corona in all districts, t… https://t.co/DxsDe8IlQo',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '1244254663664230406',
#    'relevance_score': '0.8571428571428571'},
#   {'created_at': '2020-04-12 18:43:04',
#    'id_str': '1249407703883145217',
#    'text': 'There Is A Life After Corona\n\nDue to the Corona Virus we have to stay at home to protect ourselves and anybody else… https://t.co/3y6RlYdWit',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '617477902',
#    'relevance_score': '0.8571428571428571'},
#   {'created_at': '2020-04-12 18:36:18',
#    'id_str': '1249406002824265728',
#    'text': '@ChouhanShivraj when rewa was free from any corona cases then why are you shifting corona patient from indore to re… https://t.co/W4QGz5TPzu',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '1157684690918076416',
#    'relevance_score': '0.8571428571428571'},
#   {'created_at': '2020-04-12 18:41:09',
#    'id_str': '1249407223538876419',
#    'text': 'There Is A Life After Corona\n\nDue to the Corona Virus we have to stay at home to protect ourselves and anybody else… https://t.co/sHJQY2hXQv',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '617477902',
#    'relevance_score': '0.8571428571428571'},
#   {'created_at': '2020-04-12 18:42:35',
#    'id_str': '1249407583934349318',
#    'text': 'Entre ter que conviver com meus parente e pegar corona eu escolho o corona',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '134967393',
#    'relevance_score': '0.8571428571428571'},
#   {'created_at': '2020-04-12 18:41:04',
#    'id_str': '1249407203351691264',
#    'text': 'Corona means crown and its from the word "Corona" you get "CORONATION". Therefore this is a season of coronation an… https://t.co/SJv4BEUjvo',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '999407770414788608',
#    'relevance_score': '0.8571428571428571'},
#   {'created_at': '2020-04-12 18:46:52',
#    'id_str': '1249408660721119232',
#    'text': 'There Is A Life After Corona\n\nDue to the Corona Virus we have to stay at home to protect ourselves and anybody else… https://t.co/UN1THRsCgY',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '617477902',
#    'relevance_score': '0.8571428571428571'},
#   {'created_at': '2020-04-12 18:39:25',
#    'id_str': '1249406785200537603',
#    'text': 'There Is A Life After Corona\n\nDue to the Corona Virus we have to stay at home to protect ourselves and anybody else… https://t.co/td4DbCWbSL',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '617477902',
#    'relevance_score': '0.8571428571428571'},
#   {'created_at': '2020-04-12 18:38:42',
#    'id_str': '1249406605927596034',
#    'text': 'The devil in America is saying to those infected with Corona virus in America," we could gas you, we could corona y… https://t.co/2lqPW5l6HL',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '1004632708453163008',
#    'relevance_score': '0.8571428571428571'},
#   {'created_at': '2020-04-12 18:29:00',
#    'id_str': '1249404165438287879',
#    'text': '@RichardBurgon @COVID_19Watch With no actual test for the Corona Virus and no Corona virus has been isolated. How c… https://t.co/CMYzWcD2Vb',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '3239398820',
#    'relevance_score': '0.8571428571428571'},
#   {'created_at': '2020-04-12 18:27:14',
#    'id_str': '1249403722343616523',
#    'text': 'We have been saying that it has been corona virus for a month.  Authorities say there is no Corona.\nTwo people died… https://t.co/hcroRd2Uvj',
#    'retweet_count': '1',
#    'favorite_count': '1',
#    'user_id_str': '1171373851898499072',
#    'relevance_score': '0.8571428571428571'},
#   {'created_at': '2020-04-12 18:37:41',
#    'id_str': '1249406348711919617',
#    'text': 'In.addition, I suspect they are counting anyone with "Corona"/flu -like symptoms, as "Corona victims," which they s… https://t.co/ZrYpksLf2Y',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '1207420143812386817',
#    'relevance_score': '0.85'},
#   {'created_at': '2020-04-12 18:33:10',
#    'id_str': '1249405213410242562',
#    'text': '@Real_Swain_ This is fake that Muslims brought corona. \n\nNot a single muslim has got corona so far.\n\nThey are prote… https://t.co/OllCSyAbMD',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '1246323728419401728',
#    'relevance_score': '0.85'},
#   {'created_at': '2020-04-12 18:32:17',
#    'id_str': '1249404989996437505',
#    'text': '@AjazkhanActor This is fake that Muslims brought corona. \n\nNot a single muslim has got corona so far.\n\nThey are pro… https://t.co/vGgLg1mOYe',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '1246323728419401728',
#    'relevance_score': '0.85'},
#   {'created_at': '2020-04-12 18:47:37',
#    'id_str': '1249408848898686976',
#    'text': "There's No case of corona virus in Anambra, all are lies, the stories they cooked of a man with corona virus escapi… https://t.co/hpMQ6M0Zg2",
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '724990372246593536',
#    'relevance_score': '0.85'},
#   {'created_at': '2020-04-12 18:34:56',
#    'id_str': '1249405657423454209',
#    'text': '@PureDehati @Being_Ridhima This is fake that Muslims brought corona. \n\nNot a single muslim has got corona so far.… https://t.co/DB1iisDH15',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '1246323728419401728',
#    'relevance_score': '0.85'},
#   {'created_at': '2020-04-12 18:32:48',
#    'id_str': '1249405120179306496',
#    'text': 'İstifayı kutlamak için sokağa çıkmayın millet-i şahanem...corona var corona bi rahat durun gari \n😂😂😂',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '464773809',
#    'relevance_score': '0.85'},
#   {'created_at': '2020-04-12 18:26:30',
#    'id_str': '1249403537005699078',
#    'text': 'Zou corona als een scheldwoord worden gebruikt later? Hmmm corona hoer klinkt nog ok tbh',
#    'retweet_count': '1',
#    'favorite_count': '7',
#    'user_id_str': '477753961',
#    'relevance_score': '0.85'},
#   {'created_at': '2020-04-12 18:44:46',
#    'id_str': '1249408131395878913',
#    'text': 'Great article written about indoor plumbing evolution and the possible redesign of homes after Corona. #corona.… https://t.co/kvkedYUGIi',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '481484530',
#    'relevance_score': '0.85'},
#   {'created_at': '2020-04-12 18:39:58',
#    'id_str': '1249406926133301257',
#    'text': 'Yıllarca yapılamayanı corona başarmak üzere.. Karl Marx tan sonraki en büyük komünist,\nDevrimci Corona dır.',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '613789497',
#    'relevance_score': '0.85'},
#   {'created_at': '2020-04-12 18:47:26',
#    'id_str': '1249408804078456833',
#    'text': "There's No case of corona virus in Anambra, all are lies, the stories they cooked of a man with corona virus escapi… https://t.co/Jc8rMV3tvq",
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '724990372246593536',
#    'relevance_score': '0.85'},
#   {'created_at': '2020-04-12 18:42:16',
#    'id_str': '1249407503126978570',
#    'text': 'Dinner conversation post Corona " how much value did you house lose during the Corona madness ? " 150k " how about… https://t.co/qyeSEIs6qp',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '1245256502518177792',
#    'relevance_score': '0.85'},
#   {'created_at': '2020-04-12 15:02:47',
#    'id_str': '1249352267687276545',
#    'text': 'Corona....जहां भी हो सुन लो 😂😂 चिट्टा चोला !! #nayapakistan  #Corona https://t.co/acm8yg9cuZ',
#    'retweet_count': '4',
#    'favorite_count': '20',
#    'user_id_str': '2409314312',
#    'relevance_score': '0.85'},
#   {'created_at': '2020-04-12 18:40:08',
#    'id_str': '1249406968000909318',
#    'text': 'Hergün açlıktan 15 bin kişi ölüyor ama corona kadar konuşulmuyor. Çünkü corona zengini de öldürüyor.',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '1221324040708685824',
#    'relevance_score': '0.85'},
#   {'created_at': '2020-04-12 18:46:55',
#    'id_str': '1249408674042281984',
#    'text': 'İyi ki bir şeyi sevdik ya. Corona yüzünden yeni oyun seçmek zorundayım şu an. Ananı sikeyim corona.',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '315811023',
#    'relevance_score': '0.84375'},
#   {'created_at': '2020-04-12 18:38:33',
#    'id_str': '1249406569797779459',
#    'text': '@SAARTEXT Wichtig ist nicht, wieviele NACH einer Corona-Infektion sterben, sondern wieviele AN einer Corona-Infektion sterben.',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '948485034675236864',
#    'relevance_score': '0.84375'},
#   {'created_at': '2020-04-12 18:33:34',
#    'id_str': '1249405315361243137',
#    'text': '@Bhuspunditam Jetiki desha ku corona jiba setiki heithaba aaau. CORONA ku follow kale thik data asiba',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '2936916679',
#    'relevance_score': '0.84375'},
#   {'created_at': '2020-04-12 15:42:38',
#    'id_str': '1249362295991554048',
#    'text': '@wakajugbe We need to prepare for the effects of post corona virus. After the war against corona virus the battle o… https://t.co/aV1m7ntpJc',
#    'retweet_count': '1',
#    'favorite_count': '0',
#    'user_id_str': '257283903',
#    'relevance_score': '0.84375'},
#   {'created_at': '2020-04-12 18:30:28',
#    'id_str': '1249404534352252933',
#    'text': 'Government Hospital Aurangabad is so irresponsible about Corona Swap test. They are not giving corona test report s… https://t.co/mE8CBKBaJ3',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '2782094634',
#    'relevance_score': '0.84375'},
#   {'created_at': '2020-04-12 18:38:32',
#    'id_str': '1249406563275571200',
#    'text': 'Kelamaan dirumah pengeluaran malah makin bertambah, semua gegara Covid-19 a.k.a Corona,~\n#COVID__19 \n#corona \n#dirumahaja \n#rindukerja',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '109723683',
#    'relevance_score': '0.84375'},
#   {'created_at': '2020-04-12 18:43:33',
#    'id_str': '1249407825425526784',
#    'text': '@sudhirchaudhary  Sir corona positive patients of satna (MP) has been shifted to rewa(MP)which has no /zero corona… https://t.co/KaAvQqtkBX',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '843715544431955968',
#    'relevance_score': '0.84375'},
#   {'created_at': '2020-04-12 18:40:42',
#    'id_str': '1249407110208684034',
#    'text': '2019 corona time: 5pm\n\n2020 corona time: every second limps along with the weight of eternity pressing down upon your soul',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '178946542',
#    'relevance_score': '0.84375'},
#   {'created_at': '2020-04-12 13:56:11',
#    'id_str': '1249335510516072448',
#    'text': '🌟ANPANMAN CORONA VERSION🌟\n\nAfter "Gogo Corona Version", this time we would like to bring a global product to y\'all!… https://t.co/zxrm8EDu5k',
#    'retweet_count': '59',
#    'favorite_count': '78',
#    'user_id_str': '1095537465408942083',
#    'relevance_score': '0.84375'},
#   {'created_at': '2020-04-12 18:28:32',
#    'id_str': '1249404048563941382',
#    'text': '@bertkreischer Just pretend that your being chased by the corona 😂 or better the corona cops 😂 of course you can. Y… https://t.co/2JZSF1x40u',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '922287907553054721',
#    'relevance_score': '0.8382352941176471'},
#   {'created_at': '2020-04-12 17:22:27',
#    'id_str': '1249387416177213442',
#    'text': 'Extra and sincere prayers for Gujranwala. I know Gujranwala is facing Corona and Corona type personalities. \nجسے ال… https://t.co/KKa1pmvCDD',
#    'retweet_count': '31',
#    'favorite_count': '613',
#    'user_id_str': '1002951011747721218',
#    'relevance_score': '0.8382352941176471'},
#   {'created_at': '2020-04-12 14:36:51',
#    'id_str': '1249345741807595526',
#    'text': 'Passive Immunisation starting in Pakistan: \nCORONA recovered patients in Karachi, please save corona patients lives… https://t.co/vMyRcFdBeK',
#    'retweet_count': '12',
#    'favorite_count': '25',
#    'user_id_str': '2342993066',
#    'relevance_score': '0.8382352941176471'},
#   {'created_at': '2020-04-12 18:46:35',
#    'id_str': '1249408591309701120',
#    'text': '@yankibuyuksezer @lebbywave Gerçekten corona dan sonra hiçbir şey eskisi gibi olmayacak...🙄 corona dünyayı tersine çeviriyor... korkuyorum🙊',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '301391453',
#    'relevance_score': '0.8382352941176471'},
#   {'created_at': '2020-04-06 05:58:13',
#    'id_str': '1247040899412111362',
#    'text': 'Lord heal the world from corona virus😭😷\n\nClick  here and download👇👇👇🔥🔥🔥\n [Music] Y-chizzy wetin They happen (corona… https://t.co/TIGRPu4sAt',
#    'retweet_count': '1',
#    'favorite_count': '1',
#    'user_id_str': '856602870321479680',
#    'relevance_score': '0.8382352941176471'},
#   {'created_at': '2020-04-12 14:19:46',
#    'id_str': '1249341444478750725',
#    'text': '*Comes corona virus*\n*India makes meme on it*\n2020: gives earthquake in Delhi\nLe corona to Indians : https://t.co/KQqldWfW6K',
#    'retweet_count': '5',
#    'favorite_count': '15',
#    'user_id_str': '1234900246108475392',
#    'relevance_score': '0.8382352941176471'},
#   {'created_at': '2020-04-12 11:45:44',
#    'id_str': '1249302681363062785',
#    'text': '@millardayo Huyu mwamba si amtafute kwanza CORONA alikojificha? Hilo dau angetoa kwa atakaetoa taarifa alikojificha adui CORONA.',
#    'retweet_count': '1',
#    'favorite_count': '8',
#    'user_id_str': '1119248779440422912',
#    'relevance_score': '0.8382352941176471'},
#   {'created_at': '2020-04-12 17:01:03',
#    'id_str': '1249382030984478720',
#    'text': 'Corona salgınını  fırsat olarak görenler Belediyelerimize kayyım atadılar ve kayyımlar corona salgını ile mücadele… https://t.co/McH2QMkTkE',
#    'retweet_count': '39',
#    'favorite_count': '147',
#    'user_id_str': '1292533710',
#    'relevance_score': '0.8333333333333334'},
#   {'created_at': '2020-04-12 18:44:36',
#    'id_str': '1249408092313436162',
#    'text': 'Tek derdimiz corona değil ki. Corona geçer, bizim başka dertlerimiz de var. Bu dava sizsiz olmaz bakanım. #SoyluİstifaEtmesin',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '1244687621642739712',
#    'relevance_score': '0.8333333333333334'},
#   {'created_at': '2020-04-12 18:12:38',
#    'id_str': '1249400045444706305',
#    'text': '@yerelkulis Valilik bu duruma acil el atmali, ulasimda calisacak personelin corona+ , corona tasiyici olmadigindan… https://t.co/OLllYL0UMe',
#    'retweet_count': '1',
#    'favorite_count': '1',
#    'user_id_str': '1215292310138818562',
#    'relevance_score': '0.8333333333333334'},
#   {'created_at': '2020-04-12 18:36:57',
#    'id_str': '1249406164275617792',
#    'text': 'apa ini efek bosen wfh karena corona?!!!\n.\n.\nCORONA SALAH APASI:( DISALAHIN MULU PERASAAN-,-\nGe lg pen ngegas monmaap.',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '1164749715558158342',
#    'relevance_score': '0.8333333333333334'},
#   {'created_at': '2020-04-12 14:57:10',
#    'id_str': '1249350857541353473',
#    'text': 'People lost their lives due to corona\nCM JaganReddy to lift lockdown in \nAndhra Pradesh\nCorona If the number of cas… https://t.co/wmVo4kvpvq',
#    'retweet_count': '6',
#    'favorite_count': '10',
#    'user_id_str': '809628513997361152',
#    'relevance_score': '0.8333333333333334'},
#   {'created_at': '2020-04-12 17:44:59',
#    'id_str': '1249393086624563202',
#    'text': '@Janardan_BJP @rshuklabjp till date not a single corona patient found at our Rewa but today 2 corona patient have s… https://t.co/9jH2jZrGrU',
#    'retweet_count': '1',
#    'favorite_count': '0',
#    'user_id_str': '735438715',
#    'relevance_score': '0.8333333333333334'},
#   {'created_at': '2020-04-12 18:38:41',
#    'id_str': '1249406601829789696',
#    'text': '#COVID19InTurkeysPrisons\n\nCorona insan ayırt etmiyor devlet neden yasa çıkarırken insan ayırt ediyor?\nCorona does n… https://t.co/PoVLc0Z881',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '2211049218',
#    'relevance_score': '0.8333333333333334'},
#   {'created_at': '2020-04-12 18:37:21',
#    'id_str': '1249406267312963584',
#    'text': 'The hidden agenda of care homes and corona virus. Choosing to infect residents clear or corona virus by sending hom… https://t.co/zbxlI6NYf0',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '3074105748',
#    'relevance_score': '0.8333333333333334'},
#   {'created_at': '2020-04-12 18:44:38',
#    'id_str': '1249408099104034816',
#    'text': 'Sombody said that nose blood often is a sign of corona virus, and im over here like dang then ive had corona virus… https://t.co/Dp9fDvmalj',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '1152596418701537280',
#    'relevance_score': '0.8333333333333334'},
#   {'created_at': '2020-04-12 17:47:43',
#    'id_str': '1249393776239325184',
#    'text': 'AP Corona Cases tagutunayi ani pilla saniks Corona virus ekkinchukune la unaru jagan mida edudam ani 😅😅 \n\n#Covid_19india',
#    'retweet_count': '13',
#    'favorite_count': '62',
#    'user_id_str': '3270245046',
#    'relevance_score': '0.8333333333333334'},
#   {'created_at': '2020-04-12 18:36:48',
#    'id_str': '1249406129962192899',
#    'text': 'My new business doing better than expected ... NOW SHIPPING TO ALL U.S. STATES. ORDER NOW !!!! CORONA CORONA .... W… https://t.co/HbAuty0YIU',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '54353301',
#    'relevance_score': '0.8333333333333334'},
#   {'created_at': '2020-04-12 18:34:45',
#    'id_str': '1249405611822981122',
#    'text': 'https://t.co/jON8r0cLKL\n\n#duyguozaslan #pazar #COVID2019 #12nisan #Corona #coronavirus #Corona #Trump suleyman soyl… https://t.co/2qeJY7vq8l',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '1242172851769270272',
#    'relevance_score': '0.8333333333333334'},
#   {'created_at': '2020-03-11 12:14:20',
#    'id_str': '1237713465000648710',
#    'text': 'It\'s Corona time.. SAC decision seems like "CORONA FARMAN" to 1.5 lakh aspirants of jk bank.. @narendramodi… https://t.co/dTC2dgiJDC',
#    'retweet_count': '12',
#    'favorite_count': '1',
#    'user_id_str': '1402380966',
#    'relevance_score': '0.8289473684210525'},
#   {'created_at': '2020-04-12 06:23:42',
#    'id_str': '1249221636240244736',
#    'text': 'Fight corona, download the Aarogya setu App and make India corona free #AarogyaSetu #IndiaFightCorona #make India c… https://t.co/SsWR5rUtPX',
#    'retweet_count': '6',
#    'favorite_count': '10',
#    'user_id_str': '792629300285419521',
#    'relevance_score': '0.8289473684210525'},
#   {'created_at': '2020-04-12 16:08:37',
#    'id_str': '1249368835280400385',
#    'text': '@wdunlap @LilBlondie45 @REDSTILETTO4 You can’t find any numbers for non-corona deaths in NYC!! Pre-corona numbers 4… https://t.co/o6Q69DCDMD',
#    'retweet_count': '6',
#    'favorite_count': '12',
#    'user_id_str': '31246281',
#    'relevance_score': '0.8289473684210525'},
#   {'created_at': '2020-04-12 18:32:58',
#    'id_str': '1249405163971866625',
#    'text': '@sambitswaraj घर से निकलो गए तो तोड़ देगे कोना कोना नहीं होने देंगे corona corona https://t.co/KBlyElj49S',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '1225834025559834624',
#    'relevance_score': '0.8289473684210525'},
#   {'created_at': '2020-04-12 18:40:39',
#    'id_str': '1249407097067802624',
#    'text': '@aajtak @chitraaum corona ko harana https://t.co/QvsuBn51aC hume ghar me hi rahna hai.corona harega aur hum jeetenge',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '1249198619690815488',
#    'relevance_score': '0.8289473684210525'},
#   {'created_at': '2020-04-09 17:47:03',
#    'id_str': '1248306446078525441',
#    'text': 'Corona virüs, tüm dünyaya Çin\'in "izole edilmiş" Wuhan şehrinden yayıldı!\n\nAncak her nasılsa Corona  Wuhan kentine… https://t.co/z6znKKVnIO',
#    'retweet_count': '2151',
#    'favorite_count': '6472',
#    'user_id_str': '707554993721774085',
#    'relevance_score': '0.8289473684210525'},
#   {'created_at': '2020-04-12 18:30:08',
#    'id_str': '1249404451397517315',
#    'text': '@yukselodabasi Ona, Corona’dan bahsederdim. Sadece Corona’dan bahsetmeyelim. 21. Yüzyılın başlarında çıkan Sars ve… https://t.co/RxSpdBWUH3',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '3853591103',
#    'relevance_score': '0.8289473684210525'},
#   {'created_at': '2020-04-12 15:57:54',
#    'id_str': '1249366137839726592',
#    'text': 'Türk Polisi yakalar...\nYakalar da işin kötüsü, beyni olmayan bu kitleye corona bile bulaşmaz...\n#corona https://t.co/FvrCE9xH6p',
#    'retweet_count': '23',
#    'favorite_count': '90',
#    'user_id_str': '3007503725',
#    'relevance_score': '0.8289473684210525'},
#   {'created_at': '2020-04-05 07:35:38',
#    'id_str': '1246703023625138176',
#    'text': '*Penolakan Jenazah Korban Corona - Buya Yahya Menjawab*\n\nDisuatu wilayah ada penolakan jenazah korban corona dengan… https://t.co/sibJ2lpvZQ',
#    'retweet_count': '71',
#    'favorite_count': '168',
#    'user_id_str': '1705801356',
#    'relevance_score': '0.8289473684210525'},
#   {'created_at': '2020-04-12 14:23:58',
#    'id_str': '1249342501422608384',
#    'text': 'Corona-Pandemie:\nForscher+Aktivisten sehen in der Missachtung der Natur\nals Auslöser für die Corona-Erkrankungen. W… https://t.co/mjJa9aoNBN',
#    'retweet_count': '9',
#    'favorite_count': '16',
#    'user_id_str': '3403949627',
#    'relevance_score': '0.8250000000000001'},
#   {'created_at': '2020-04-12 18:29:02',
#    'id_str': '1249404172480294914',
#    'text': '@_garrywalia Jaise studio me baith kar reporting karne wale Corona warrior nahi hote, asli Corona warrior journalis… https://t.co/8AgyhXQURt',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '1056278210554429440',
#    'relevance_score': '0.8250000000000001'},
#   {'created_at': '2020-04-11 20:47:58',
#    'id_str': '1249076749478105098',
#    'text': '#Corona ist eine PSYOP der WHO, die von reichen Männern dominiert wird. Die Kriegslüge: Corona, ein Erkältungsvirus… https://t.co/pfSXe78VVV',
#    'retweet_count': '3',
#    'favorite_count': '2',
#    'user_id_str': '341367267',
#    'relevance_score': '0.8250000000000001'},
#   {'created_at': '2020-04-12 18:31:56',
#    'id_str': '1249404904516485124',
#    'text': 'Ey corona! Ey corona! Tesekkurler . Mahallemizde sokaga cikma yasagi var yoksa halay cekerdik @sark kahvesi sakinle… https://t.co/JX6ILD0svp',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '337906475',
#    'relevance_score': '0.8250000000000001'},
#   {'created_at': '2020-04-12 18:40:33',
#    'id_str': '1249407070727782402',
#    'text': '"Vai tomar no cu o corona, morreu e deixou o virus, vai tomar no cu o corona" \nMorcego, Ricardo vulgo meu tio',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '2245780799',
#    'relevance_score': '0.8250000000000001'},
#   {'created_at': '2020-04-12 09:24:56',
#    'id_str': '1249267248000389121',
#    'text': "86 yaşında corona virüsü yenmişti, hayatını kaybetti..\n\nSakarya'da 86 yaşında corona virüsü yenen Resmiye Işık, bey… https://t.co/lT8Ws7OVnl",
#    'retweet_count': '51',
#    'favorite_count': '256',
#    'user_id_str': '2762143991',
#    'relevance_score': '0.8250000000000001'},
#   {'created_at': '2020-04-12 18:44:20',
#    'id_str': '1249408024130641928',
#    'text': 'World (accept India) has only one problem -\n1.CORONA\nBut India has -\n1. Corona\n2. Tablighi Jamati (Thook gang)\n3. K… https://t.co/UQh08PAOEp',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '3257466091',
#    'relevance_score': '0.8214285714285715'},
#   {'created_at': '2020-04-12 18:30:24',
#    'id_str': '1249404517667479553',
#    'text': 'Arkadşlar bu corona havadan geçiyor mu ya geçiyorsa corona olucam gibi hissediyorum mağlum bizim buraya gelmiş dldl… https://t.co/n0hzNDDRQB',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '1161907081605197824',
#    'relevance_score': '0.8214285714285715'},
#   {'created_at': '2020-04-10 14:00:01',
#    'id_str': '1248611696840544256',
#    'text': "14) Avustralya Grand Prixi CORONA yüzünden İPTAL edildiği haberinde bile TR'den CAMI FOTOĞRAFI vardı.\n\nCorona-TR-Ca… https://t.co/ffZBWUprEj",
#    'retweet_count': '84',
#    'favorite_count': '181',
#    'user_id_str': '4832975056',
#    'relevance_score': '0.8214285714285715'},
#   {'created_at': '2020-04-12 18:47:19',
#    'id_str': '1249408775846416386',
#    'text': 'INDORE में जहां Corona Warriors पर पथराव हुआ था, वहीं गूँज उठी तालियां In INDORE, where the Corona Warriors were st… https://t.co/6y2xDUUncp',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '955509381843402752',
#    'relevance_score': '0.8214285714285715'},
#   {'created_at': '2020-04-12 18:35:36',
#    'id_str': '1249405827007512577',
#    'text': '@suleymansoylu   ayrıldı ne demek ya. Ulke sadece Corona ile mücadele etmiyor ki . Corona illetini atlatırız da bu… https://t.co/XkMLPtmULC',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '125394682',
#    'relevance_score': '0.8214285714285715'},
#   {'created_at': '2020-04-12 17:33:48',
#    'id_str': '1249390274163269632',
#    'text': '@electaegguk Lg pandemik corona. Padahal katanya corona menyerang pernafasan ya? Harusnya paru paru yg rusak kan, k… https://t.co/3BF7vfFduF',
#    'retweet_count': '1',
#    'favorite_count': '5',
#    'user_id_str': '1082991932001775616',
#    'relevance_score': '0.8214285714285715'},
#   {'created_at': '2020-04-11 20:10:10',
#    'id_str': '1249067238856044544',
#    'text': '41.947 orang penderita terpapar corona Iran sembuh, Iran produksi massal vaksin virus Corona dari plasma penderita… https://t.co/oKcCDasYiH',
#    'retweet_count': '392',
#    'favorite_count': '1159',
#    'user_id_str': '727998262137905152',
#    'relevance_score': '0.8214285714285715'},
#   {'created_at': '2020-04-12 18:39:10',
#    'id_str': '1249406725838471169',
#    'text': 'Corona bütün planları değiştirdi genelde "deprem sel çığ" istifa eden olmuyordu corona istifası bu "bu partinin "ka… https://t.co/YCyJLJMjzL',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '1164982782680023041',
#    'relevance_score': '0.8214285714285715'},
#   {'created_at': '2020-04-12 18:41:54',
#    'id_str': '1249407412563513346',
#    'text': '@BBahadirErdem HOCAM BU CORONA İKTİDARA ZARARI ÇOK FAZLA OLUR DİYORDUK  CORONA SALGINIDA GÜN GEÇMİYOR Kİ HATALAR Zİ… https://t.co/zfeQQHsSf6',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '3347454417',
#    'relevance_score': '0.8214285714285715'},
#   {'created_at': '2020-04-12 14:55:24',
#    'id_str': '1249350412060119040',
#    'text': 'Gub Jateng @ganjarpranowo Tlp pasien sembuh corona\n\nGub Jatim @KhofifahIP sapa pasien sembuh corona lewat video con… https://t.co/W4PTlO2xRo',
#    'retweet_count': '45',
#    'favorite_count': '172',
#    'user_id_str': '821859629034409985',
#    'relevance_score': '0.8214285714285715'},
#   {'created_at': '2020-04-12 17:08:50',
#    'id_str': '1249383990999408641',
#    'text': 'Some Corona +ve criminals sent fm Corona hotspot Indore to Satna Jail &amp; now shifted to Rewa medical college. Immedi… https://t.co/m5BJ0lccnp',
#    'retweet_count': '3',
#    'favorite_count': '4',
#    'user_id_str': '855254681844449280',
#    'relevance_score': '0.8214285714285715'},
#   {'created_at': '2020-04-11 05:35:46',
#    'id_str': '1248847186466496514',
#    'text': 'Kalau kuman virus corona masuk dalam tanah bakal terjadi apa?\n\nInsyaAllah si corona dikeroyok oleh triliunan mikrob… https://t.co/HeoBCiJ9Si',
#    'retweet_count': '906',
#    'favorite_count': '2677',
#    'user_id_str': '1052703629528854530',
#    'relevance_score': '0.8214285714285715'},
#   {'created_at': '2020-04-12 18:46:46',
#    'id_str': '1249408635408650242',
#    'text': '1. Mai: Gemeinsam kämpfen gegen Corona und Krise!\n Teilen und am 1. Mai sichtbar sein! Corona- und Wirtschaftskrise… https://t.co/ClLj7zbN1F',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '970654281832501249',
#    'relevance_score': '0.8214285714285715'},
#   {'created_at': '2020-04-12 18:42:22',
#    'id_str': '1249407529555197952',
#    'text': '@KlasraRauf Kalasrs sb, aap ne corona pe abi tak thesis nai kiya?? Seyasat ko chorein aur corona oe awam ko bhaashan dein.',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '328457185',
#    'relevance_score': '0.8181818181818181'},
#   {'created_at': '2020-04-12 18:43:20',
#    'id_str': '1249407772682153984',
#    'text': '@RubikaLiyaquat  corona mukt rewa  district me 2 corona positive marijo ko laya jana ek bhut achmbhit karne wali ba… https://t.co/Kv86r0R407',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '1328323495',
#    'relevance_score': '0.8181818181818181'},
#   {'created_at': '2020-04-12 18:45:02',
#    'id_str': '1249408200526495748',
#    'text': 'corona vírus gizelly bbb20 follow trick #followtrick +18 babu corona manu tiago gizelly daniel fim mundo thelma kpo… https://t.co/i2hYl9pS6f',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '1249222713123708933',
#    'relevance_score': '0.8181818181818181'},
#   {'created_at': '2020-04-12 18:38:29',
#    'id_str': '1249406553272094722',
#    'text': 'Jangan ada yang bilang trrjangkit virus corona, corona tidak ada yg mati mendadak bung, biasanya penyakit jantung b… https://t.co/cbQPKFOLxc',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '1243601423146848259',
#    'relevance_score': '0.8181818181818181'},
#   {'created_at': '2020-04-12 18:46:11',
#    'id_str': '1249408487936811008',
#    'text': '@chitraaum corona mukt rewa  district me 2 corona positive marijo ko laya jana ek bhut achmbhit karne wali bat hai.… https://t.co/WIqYUheEOH',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '1328323495',
#    'relevance_score': '0.8152173913043478'},
#   {'created_at': '2020-04-12 18:31:25',
#    'id_str': '1249404772366639109',
#    'text': '@annammathis Mano a primeira morte por corona no Brasil só foi ser tratado como corona depois da morte. O cara prec… https://t.co/BYRTxPIms7',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '470518431',
#    'relevance_score': '0.8152173913043478'},
#   {'created_at': '2020-04-12 18:32:25',
#    'id_str': '1249405025098575878',
#    'text': 'Lees "Kun je een tweede keer zieker worden van corona?" op Nieuwsblik - https://t.co/sVPmhRN3iD - Wie corona krijgt… https://t.co/mSfq1TTPjT',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '1037266384235966464',
#    'relevance_score': '0.8152173913043478'},
#   {'created_at': '2020-04-12 06:43:59',
#    'id_str': '1249226741350125569',
#    'text': 'Die JU ist für die automatische Installation der Corona-Überwachungsapp.\nWer denkt, dass diese App nur die Corona-K… https://t.co/YgE3kbmyEw',
#    'retweet_count': '109',
#    'favorite_count': '191',
#    'user_id_str': '992360479254351872',
#    'relevance_score': '0.8152173913043478'},
#   {'created_at': '2020-04-12 18:45:03',
#    'id_str': '1249408203634298880',
#    'text': 'Dampak Corona, 45 Ribu Wisman Batal ke Flores - Cendana News: Dampak Corona, 45 Ribu Wisman Batal ke Flores\xa0\xa0Cendan… https://t.co/tueTZQa4R7',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '1362549109',
#    'relevance_score': '0.8152173913043478'},
#   {'created_at': '2020-04-12 18:33:04',
#    'id_str': '1249405188240216067',
#    'text': '2 hafta sonra corona vaka sayısı 3 4 katına çıktığında bunun da hesabını verebilecek misin acaba?\nCorona olayında b… https://t.co/NBEaUA4yrm',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '344319933',
#    'relevance_score': '0.8152173913043478'},
#   {'created_at': '2020-04-12 11:45:53',
#    'id_str': '1249302718977429504',
#    'text': 'Saat ini, sudah tidak ada lagi pasien positif Corona di Provinsi Aceh.\n\nKabar Baik! Seluruh Pasien Positif Corona d… https://t.co/8zZbOAf5AB',
#    'retweet_count': '316',
#    'favorite_count': '1088',
#    'user_id_str': '299951071',
#    'relevance_score': '0.8152173913043478'},
#   {'created_at': '2020-04-12 17:01:39',
#    'id_str': '1249382182898065408',
#    'text': '1. Corona är en mycket svår belastning på vårt samhälle, men att Corona är allvarligt gör inte krigsliknelser rikti… https://t.co/qJPE64dBD5',
#    'retweet_count': '12',
#    'favorite_count': '36',
#    'user_id_str': '2712776092',
#    'relevance_score': '0.8152173913043478'},
#   {'created_at': '2020-04-12 17:41:17',
#    'id_str': '1249392156265132032',
#    'text': 'Ostern vor Corona:\n"BOAH, scheiße. Ich muss die Familie sehen."\n\nOstern während Corona:\n"Es tut sooo weh, die Famil… https://t.co/OCctwSCXbr',
#    'retweet_count': '7',
#    'favorite_count': '55',
#    'user_id_str': '2435691',
#    'relevance_score': '0.8152173913043478'},
#   {'created_at': '2020-04-12 18:46:42',
#    'id_str': '1249408617846980609',
#    'text': '@narendramodi corona mukt rewa  district me 2 corona positive marijo ko laya jana ek bhut achmbhit karne wali bat h… https://t.co/EXHROESF8d',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '1328323495',
#    'relevance_score': '0.8152173913043478'},
#   {'created_at': '2020-04-12 18:43:04',
#    'id_str': '1249407703945887745',
# ...
#    'text': 'Corona siyasetçileri farklı dalga ile götürüyor varan1',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '130834893',
#    'relevance_score': '0.5714285714285714'},
#   {'created_at': '2020-04-12 18:30:41',
#    'id_str': '1249404588177981441',
#    'text': 'Who upset corona Bhaisab? https://t.co/UFhUaka6p5',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '1136366183664553986',
#    'relevance_score': '0.5714285714285714'},
#   {'created_at': '2020-04-12 18:37:14',
#    'id_str': '1249406236233289730',
#    'text': '@AbuDaDon__ I will mf cause clearly Nashville where the corona',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '570558037',
#    'relevance_score': '0.5714285714285714'},
#   {'created_at': '2020-04-12 18:36:31',
#    'id_str': '1249406057186762753',
#    'text': 'Corona bi git de yolumuza bakalım nolur',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '1234100391907921922',
#    'relevance_score': '0.5714285714285714'},
#   {'created_at': '2020-04-12 18:31:00',
#    'id_str': '1249404666938626049',
#    'text': '@aylin_atg Corona: dur daha yeni başladık bro',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '1210655783253352449',
#    'relevance_score': '0.5714285714285714'},
#   {'created_at': '2020-04-12 18:37:12',
#    'id_str': '1249406228444450817',
#    'text': 'Corona Arc got great character development thoo',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '1152530224829128704',
#    'relevance_score': '0.5714285714285714'},
#   {'created_at': '2020-04-12 18:28:30',
#    'id_str': '1249404040078929920',
#    'text': '@proudbmay corona n faz nd por nós',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '1063956105179668480',
#    'relevance_score': '0.5714285714285714'},
#   {'created_at': '2020-04-12 18:44:22',
#    'id_str': '1249408032649469965',
#    'text': 'Idiot number one off Belgium.\nHope you get #Corona',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '342607723',
#    'relevance_score': '0.5714285714285714'},
#   {'created_at': '2020-04-12 18:37:01',
#    'id_str': '1249406181858148353',
#    'text': '"One Directions vocals are powerful than the corona virus" YES',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '959666699543826432',
#    'relevance_score': '0.5714285714285714'},
#   {'created_at': '2020-04-12 18:42:50',
#    'id_str': '1249407647922688005',
#    'text': '@sagesmoke11 Yes yes... imma get one after Corona',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '376260422',
#    'relevance_score': '0.5714285714285714'},
#   {'created_at': '2020-04-12 18:28:37',
#    'id_str': '1249404067459272705',
#    'text': '@AlineQ12 A pneumonia é uma das decorrencias do corona',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '190924319',
#    'relevance_score': '0.5714285714285714'},
#   {'created_at': '2020-04-12 18:34:16',
#    'id_str': '1249405490116866050',
#    'text': 'Corona allahın varsa defol git ya nolursun😩😩',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '1053367870024007685',
#    'relevance_score': '0.5714285714285714'},
#   {'created_at': '2020-04-12 18:30:35',
#    'id_str': '1249404562194280450',
#    'text': 'Corona virus 😬 https://t.co/NtKSvN7Os0',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '1220829297486725122',
#    'relevance_score': '0.5714285714285714'},
#   {'created_at': '2020-04-12 18:34:22',
#    'id_str': '1249405517878816768',
#    'text': '@TOICitiesNews Lockdown n fear of Corona n starvation',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '189297596',
#    'relevance_score': '0.5714285714285714'},
#   {'created_at': '2020-04-11 22:44:07',
#    'id_str': '1249105981742686209',
#    'text': '"2020 vai ser o ano"\n\ncorona vírus:',
#    'retweet_count': '22',
#    'favorite_count': '6',
#    'user_id_str': '797502615978438656',
#    'relevance_score': '0.5714285714285714'},
#   {'created_at': '2020-04-12 18:37:29',
#    'id_str': '1249406301660229632',
#    'text': 'The corona virus in color  https://t.co/ScW18WACOx',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '301055281',
#    'relevance_score': '0.5714285714285714'},
#   {'created_at': '2020-04-12 18:32:29',
#    'id_str': '1249405040994816001',
#    'text': 'corona really made me give up seeing my friends for lent',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '773441034114195458',
#    'relevance_score': '0.5714285714285714'},
#   {'created_at': '2020-04-12 18:28:45',
#    'id_str': '1249404100493684741',
#    'text': '@MeganMsschln @Mariem_Idr die is duidelijk getroffen door Corona',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '823639353167646722',
#    'relevance_score': '0.5714285714285714'},
#   {'created_at': '2020-04-12 18:36:29',
#    'id_str': '1249406048575856646',
#    'text': '@Osman5Salak Gezinin başaramadığını corona mi başarıyor yoksa',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '395776053',
#    'relevance_score': '0.5714285714285714'},
#   {'created_at': '2020-04-11 22:20:51',
#    'id_str': '1249100125760155650',
#    'text': 'Saudades de quando corona era só cerveja',
#    'retweet_count': '4',
#    'favorite_count': '7',
#    'user_id_str': '1011425382179004416',
#    'relevance_score': '0.5714285714285714'},
#   {'created_at': '2020-04-12 07:44:29',
#    'id_str': '1249241967168536578',
#    'text': 'Street life during #corona https://t.co/NIUTxu0z9C',
#    'retweet_count': '90',
#    'favorite_count': '432',
#    'user_id_str': '721390246756282371',
#    'relevance_score': '0.5714285714285714'},
#   {'created_at': '2020-04-12 18:44:55',
#    'id_str': '1249408170239221761',
#    'text': '@narendramodi गर्म पानी पियो corona भाग जाएगा',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '1225834025559834624',
#    'relevance_score': '0.5714285714285714'},
#   {'created_at': '2020-04-12 18:26:23',
#    'id_str': '1249403506412445699',
#    'text': '⚠️ leseempfehlung ⚠️\nCorona!!!\nBitte🔃🔃🔃🔃🔃\nretweeten ‼‼‼\n#antifaforhelp',
#    'retweet_count': '1',
#    'favorite_count': '0',
#    'user_id_str': '1078419185968074752',
#    'relevance_score': '0.5714285714285714'},
#   {'created_at': '2020-03-23 19:19:03',
#    'id_str': '1242169003361144832',
#    'text': '“ Corona Various “ 🤣.. https://t.co/8ytH3T329r',
#    'retweet_count': '4082',
#    'favorite_count': '12349',
#    'user_id_str': '737856637055209472',
#    'relevance_score': '0.5714285714285714'},
#   {'created_at': '2020-04-12 18:32:41',
#    'id_str': '1249405094380163074',
#    'text': '@nypost Breaking. The corona virus is a low grade virus',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '44458266',
#    'relevance_score': '0.5714285714285714'},
#   {'created_at': '2020-04-12 15:04:52',
#    'id_str': '1249352793313497090',
#    'text': 'Nasil gidiyor corona https://t.co/8Py17LNUQl',
#    'retweet_count': '21',
#    'favorite_count': '306',
#    'user_id_str': '1162400469966315520',
#    'relevance_score': '0.5714285714285714'},
#   {'created_at': '2020-04-12 18:38:18',
#    'id_str': '1249406507143311360',
#    'text': 'Corona bitti deseler bu kadar şaşırmazdım herhalde',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '1244408867951448066',
#    'relevance_score': '0.5714285714285714'},
#   {'created_at': '2020-04-12 18:37:16',
#    'id_str': '1249406247226339328',
#    'text': '@putueric Corona masalah kecil, kami butuh piknik',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '1133139232392826881',
#    'relevance_score': '0.5714285714285714'},
#   {'created_at': '2020-04-12 18:28:30',
#    'id_str': '1249404041508958209',
#    'text': '@Cernovich Corona Bros = Just Following Orders Crew',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '1074844774362824704',
#    'relevance_score': '0.5714285714285714'},
#   {'created_at': '2020-04-12 18:28:22',
#    'id_str': '1249404004184084481',
#    'text': 'Pfv corona eu preciso fazer minhas unhas',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '4918795455',
#    'relevance_score': '0.5714285714285714'},
#   {'created_at': '2020-04-12 18:30:04',
#    'id_str': '1249404431889653761',
#    'text': 'Send me a tiddy and I’ll let you know if you immune to corona or not',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '25607427',
#    'relevance_score': '0.5714285714285714'},
#   {'created_at': '2020-04-12 18:29:21',
#    'id_str': '1249404251974930432',
#    'text': 'is penat kali lo, cpt2 la corona ilang',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '198402207',
#    'relevance_score': '0.5714285714285714'},
#   {'created_at': '2020-04-12 18:28:40',
#    'id_str': '1249404082151964673',
#    'text': '@nvalerios e de brinde ganha o corona',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '892420363',
#    'relevance_score': '0.5714285714285714'},
#   {'created_at': '2020-04-12 18:39:31',
#    'id_str': '1249406812585185280',
#    'text': '@Carpervert Been chased by a corona, but bog roll to the ready 😂',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '40089039',
#    'relevance_score': '0.5714285714285714'},
#   {'created_at': '2020-04-12 15:51:58',
#    'id_str': '1249364645703540738',
#    'text': 'blurry corona fit https://t.co/1MCI834Gxg',
#    'retweet_count': '1',
#    'favorite_count': '2',
#    'user_id_str': '865572729402949632',
#    'relevance_score': '0.5714285714285714'},
#   {'created_at': '2020-04-12 18:39:59',
#    'id_str': '1249406928830201858',
#    'text': 'REMEMBER PEOPLE CHRIST IS RISEN NOT CORONA STAY SAFE',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '343503327',
#    'relevance_score': '0.5714285714285714'},
#   {'created_at': '2020-04-12 18:41:12',
#    'id_str': '1249407234217558016',
#    'text': '@Haffy_h lol sorry . Blame corona virus 😭',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '173031467',
#    'relevance_score': '0.5714285714285714'},
#   {'created_at': '2020-04-12 18:44:48',
#    'id_str': '1249408141365739521',
#    'text': '@thecasanovaaa when corona dies we gonna get drunk together',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '4249930415',
#    'relevance_score': '0.5714285714285714'},
#   {'created_at': '2020-04-12 18:29:55',
#    'id_str': '1249404396800217090',
#    'text': 'Corona kılıç gibi biçiyor yerleşik olan her şeyi',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '1087483247750270977',
#    'relevance_score': '0.5714285714285714'},
#   {'created_at': '2020-04-11 09:39:49',
#    'id_str': '1248908602779336704',
#    'text': 'im so tired of this corona shit im irritated at this point',
#    'retweet_count': '21',
#    'favorite_count': '22',
#    'user_id_str': '2479807916',
#    'relevance_score': '0.5714285714285714'},
#   {'created_at': '2020-04-12 18:24:02',
#    'id_str': '1249402914268905475',
#    'text': 'Aooooooo saudadeee do meu galooooo corona vírus fedaputaaa',
#    'retweet_count': '2',
#    'favorite_count': '0',
#    'user_id_str': '1036423345393344512',
#    'relevance_score': '0.5714285714285714'},
#   {'created_at': '2020-04-12 18:37:47',
#    'id_str': '1249406377170210820',
#    'text': '@kingflaymes @Selorm1_ At Last, Vaccine for Corona virus discovered',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '3025577069',
#    'relevance_score': '0.5714285714285714'},
#   {'created_at': '2020-04-12 18:39:34',
#    'id_str': '1249406824392122369',
#    'text': 'Corona vírus não existe e uma besteira',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '2990085365',
#    'relevance_score': '0.5714285714285714'},
#   {'created_at': '2020-04-12 12:14:34',
#    'id_str': '1249309937634811912',
#    'text': "Hi, I don't care what Karl Friston says about the Corona virus.",
#    'retweet_count': '2',
#    'favorite_count': '27',
#    'user_id_str': '861642277952860162',
#    'relevance_score': '0.5714285714285714'},
#   {'created_at': '2020-04-12 18:35:19',
#    'id_str': '1249405756870479872',
#    'text': '@maisa Manda ele matar esse corona então!',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '1038582615979294720',
#    'relevance_score': '0.5714285714285714'},
#   {'created_at': '2020-04-12 18:46:52',
#    'id_str': '1249408661308481537',
#    'text': '@Bridget_Otoo Now I am sure there is a glitch in the Matrix. Ebola and Corona how???',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '152416975',
#    'relevance_score': '0.5714285714285714'},
#   {'created_at': '2020-04-12 18:39:07',
#    'id_str': '1249406712571760640',
#    'text': 'Diwakilkan oleh lagu dan terlindungi karena corona',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '547381240',
#    'relevance_score': '0.5714285714285714'},
#   {'created_at': '2020-04-12 18:27:04',
#    'id_str': '1249403677003132928',
#    'text': '#Streeck ist durch, oder?\n\n#corona #coronavirus #COVID19',
#    'retweet_count': '1',
#    'favorite_count': '0',
#    'user_id_str': '841021776238936069',
#    'relevance_score': '0.5714285714285714'},
#   {'created_at': '2020-04-12 14:40:35',
#    'id_str': '1249346683735085063',
#    'text': '⚠️ leseempfehlung ⚠️\nCorona!!!\nBitte🔃🔃🔃🔃🔃\nretweeten ‼‼‼\n#antifaforhelp',
#    'retweet_count': '1',
#    'favorite_count': '0',
#    'user_id_str': '1078419185968074752',
#    'relevance_score': '0.5714285714285714'},
#   {'created_at': '2020-04-12 18:35:00',
#    'id_str': '1249405675442262016',
#    'text': 'corona:\nour minister of interior: resigned \nour minister of communications: dismissed',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '1000135976629489665',
#    'relevance_score': '0.5714285714285714'},
#   {'created_at': '2020-04-12 18:43:46',
#    'id_str': '1249407882254331907',
#    'text': '@velisacilik Corona vürüse aşı bulunmuş gibi sevindim😂',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '358383486',
#    'relevance_score': '0.5714285714285714'},
#   {'created_at': '2020-04-12 18:38:24',
#    'id_str': '1249406529700167680',
#    'text': '@gureumoon corona hyungg,, kita pake zoom sj',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '949565985610113024',
#    'relevance_score': '0.5714285714285714'},
#   {'created_at': '2020-04-12 18:11:48',
#    'id_str': '1249399837226917891',
#    'text': 'Corona made me do this 😩😩😩😩😩😩 https://t.co/McqTN6vxtf',
#    'retweet_count': '2',
#    'favorite_count': '3',
#    'user_id_str': '215884688',
#    'relevance_score': '0.5714285714285714'},
#   {'created_at': '2020-04-12 18:38:16',
#    'id_str': '1249406498276438016',
#    'text': '@kuahsayurasem_ @andihiyat gbole keluar heh ad corona!',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '1221291806307975170',
#    'relevance_score': '0.5714285714285714'},
#   {'created_at': '2020-04-12 16:35:54',
#    'id_str': '1249375704967524356',
#    'text': 'this corona shit just getting annoying bruh #freetheUnitedStates',
#    'retweet_count': '3',
#    'favorite_count': '3',
#    'user_id_str': '2298787394',
#    'relevance_score': '0.5714285714285714'},
#   {'created_at': '2020-04-12 18:43:35',
#    'id_str': '1249407835831599105',
#    'text': '@Lmh251 @BTS_twt @BigHitEnt @bighit_merch Lagi Corona hyung',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '1206789212743196673',
#    'relevance_score': '0.5714285714285714'},
#   {'created_at': '2020-04-12 18:45:09',
#    'id_str': '1249408231094595586',
#    'text': 'corona sayesinde neler oluyor yaradan nelere kadir',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '462906731',
#    'relevance_score': '0.5714285714285714'},
#   {'created_at': '2020-04-12 18:47:27',
#    'id_str': '1249408806989099008',
#    'text': '@bungyana_ Siajik, doakeun mah corona leungit. 😂😂',
#    'retweet_count': '0',
#    'favorite_count': '0',
#    'user_id_str': '341965931',
#    'relevance_score': '0.5714285714285714'},
#   ...],
#  'fetch_time': 0.8134949207305908}

# %% [markdown]
# ### top_10

# %%
def get_top_data(data_type):
    try:
        if data_type == "users":
            cur.execute(f"""SELECT name,id_str, screen_name, followers_count, friends_count, verified, description, location FROM user_data ORDER BY followers_count DESC LIMIT 10""")
            user_data = cur.fetchall()
            db_final = pd.DataFrame(user_data, columns=['name', 'id_str','screen_name', 'followers_count', 'friends_count', 'verified', 'description', 'location']) 
            output = json.loads(db_final.to_json(orient='records', date_format='iso'))
            return output

        elif data_type == "tweets":
            tweets = c1.find({}, {"text": 1, "user_id_str": 1, '_id': 0}).sort("retweet_count", -1).limit(10)
            db_final = pd.DataFrame(list(tweets))
            for index, row in db_final.iterrows():
                user_id = row['user_id_str'].strip()
                cur.execute(f"""SELECT screen_name FROM user_data WHERE id_str = '{user_id}'""")
                user_data = cur.fetchone()

                if user_data:
                    user_info = list(user_data)
                    db_final.loc[index, 'screen_name'] = user_info[0]

            #db_final.drop('user_id_str',axis=1,inplace=True)
                    
             # Apply the function to the DataFrame
            db_final_encoded = db_final.map(handle_non_utf8)

            # Convert the DataFrame to JSON
            output = json.loads(db_final_encoded.to_json(orient='records', date_format='iso'))
            return output

        else:
            print("Invalid data type")
            return None
    except Exception as e:
        print(f"Retrieval of data failed: {e}")

# %%
get_top_data('tweets')
# Out:
# [{'text': 'ALERT‼️‼️‼️\nThe corona virus can be spread through money. If you have any money at home, put on some gloves, put al… https://t.co/juJjDpFN3I',
#   'user_id_str': '2863558530',
#   'screen_name': 'nan'},
#  {'text': 'THIS MAN IS A GENIUS he figured out the Corona virus problem 😮 https://t.co/EZP7IqTtxV',
#   'user_id_str': '1131227186',
#   'screen_name': '_AyeeCarlos_'},
#  {'text': 'Watch this. It shows why we should all do the right thing and stay home to the fullest extent possible. All of us c… https://t.co/GOODRTNI2e',
#   'user_id_str': '813286',
#   'screen_name': 'BarackObama'},
#  {'text': 'If I gave you 100 skittles and told you 3 of them could kill you.... I’m sure you would avoid the fucking skittles',
#   'user_id_str': '29942414',
#   'screen_name': 'nan'},
#  {'text': 'It wasn’t no corona till y’all started balancing brooms in the house, y’all let the devil in',
#   'user_id_str': '219582851',
#   'screen_name': 'nan'},
#  {'text': 'Corona virus....its coming',
#   'user_id_str': '1242575784',
#   'screen_name': 'Marco_Acortes'},
#  {'text': 'we all know who the only person who can defeat corona is https://t.co/u7DraiQHHY',
#   'user_id_str': '784597616269156352',
#   'screen_name': 'nan'},
#  {'text': 'CDC just announced that corona can be spread via Instagram story challenges :-/',
#   'user_id_str': '770284073805815819',
#   'screen_name': 'omer___go'},
#  {'text': 'This what Corona do when you outta school for 2 weeks &amp; home w ya mama 😂😂😂🤦🏾\u200d♀️ https://t.co/bz4u2p2JZM',
#   'user_id_str': '2315563859',
#   'screen_name': 'Sydneyy_Alexiss'},
#  {'text': 'sinceramente to meio sem tempo pra esse tal de corona virus to cheia de coisa pra resolver espero q ele entenda e respeite o meu espaço',
#   'user_id_str': '759632021975134208',
#   'screen_name': 'rayannemendesss'}]

# %%
get_top_data('users')
# Out:
# [{'name': 'Barack Obama',
#   'id_str': '813286',
#   'screen_name': 'BarackObama',
#   'followers_count': 115603427,
#   'friends_count': 607612,
#   'verified': True,
#   'description': 'Dad, husband, President, citizen.',
#   'location': 'Washington, DC'},
#  {'name': 'Narendra Modi',
#   'id_str': '18839785',
#   'screen_name': 'narendramodi',
#   'followers_count': 55406011,
#   'friends_count': 2368,
#   'verified': True,
#   'description': 'Prime Minister of India',
#   'location': 'India'},
#  {'name': 'Virender Sehwag',
#   'id_str': '92724677',
#   'screen_name': 'virendersehwag',
#   'followers_count': 20571543,
#   'friends_count': 143,
#   'verified': True,
#   'description': 'Proud Indian | For commercial queries, call my manager @AmritanshuGupta on +91 9873690935 | For @SehwagSchool , call +91 9711188700',
#   'location': 'India'},
#  {'name': 'detikcom',
#   'id_str': '69183155',
#   'screen_name': 'detikcom',
#   'followers_count': 15884915,
#   'friends_count': 28,
#   'verified': True,
#   'description': 'Official Twitter of http://www.detik.com. redaksi@detik.com | promosi@detik.com | Android: http://detik.com/android iPhone: http://detik.com/iphone',
#   'location': 'Jakarta, Indonesia'},
#  {'name': 'Rahul Gandhi',
#   'id_str': '3171712086',
#   'screen_name': 'RahulGandhi',
#   'followers_count': 13107722,
#   'friends_count': 253,
#   'verified': True,
#   'description': 'This is the official account of Rahul Gandhi | Member of the Indian National Congress| Member of Parliament',
#   'location': '12, Tughlak Lane, New Delhi'},
#  {'name': 'Gautam Gambhir',
#   'id_str': '99448420',
#   'screen_name': 'GautamGambhir',
#   'followers_count': 10476847,
#   'friends_count': 126,
#   'verified': True,
#   'description': 'Former Cricketer. Member of Honourable Parliament (East Delhi).',
#   'location': None},
#  {'name': 'Cole M. Sprouse',
#   'id_str': '266336410',
#   'screen_name': 'colesprouse',
#   'followers_count': 9914883,
#   'friends_count': 205,
#   'verified': True,
#   'description': 'super cool and nice guy',
#   'location': 'Tubbytronic Superdome'},
#  {'name': 'aajtak',
#   'id_str': '42606652',
#   'screen_name': 'aajtak',
#   'followers_count': 9524707,
#   'friends_count': 418,
#   'verified': True,
#   'description': 'AajTak covers breaking news, latest news in politics, sports, business & cinema. Follow us & stay ahead! Download the App:   https://aajtak.app.link/QFAp3ZaHmQ',
#   'location': 'India'},
#  {'name': 'ABP News',
#   'id_str': '39240673',
#   'screen_name': 'ABPNews',
#   'followers_count': 9469973,
#   'friends_count': 248,
#   'verified': True,
#   'description': 'Follow for latest news alerts from India',
#   'location': 'India'},
#  {'name': 'Rajdeep Sardesai',
#   'id_str': '56304605',
#   'screen_name': 'sardesairajdeep',
#   'followers_count': 8931083,
#   'friends_count': 565,
#   'verified': True,
#   'description': "Citizen first. Only 'ism' is humanism. newsman, tv anchor, author, father, friend. New book: 2019: How Modi Won India. pre order here: http://bit.ly/HowModiWon",
#   'location': 'New Delhi'}]

# %% [markdown]
# ### search_retweets

# %%
def search_retweets(tweet_id):
    try:
        if tweet_id:
            pipeline = [
                {
                    "$match": {
                        "org_tweet_id": tweet_id
                    }
                },
                {
                    "$project": {
                        "id_str":1,
                        "user_id_str": 1,
                        "created_at":1,
                        "text":1
                    }
                }
            ]
            db_final = pd.DataFrame(list(c2.aggregate(pipeline)))
            print(db_final)
            # Fetch user information and add to DataFrame
            for index, row in db_final.iterrows():
                user_id = row['user_id_str']
                cur.execute(f"""SELECT screen_name FROM user_data WHERE id_str = '{user_id}'""")
                user_data = cur.fetchone()
                if user_data:
                    user_info = list(user_data)
                    db_final.loc[index, 'screen_name'] = user_info[0]
                    
            # Drop unnecessary columns
            db_final = db_final.drop(['_id', 'user_id_str'], axis=1)
            db_final_encoded = db_final.map(handle_non_utf8)
            # Convert the DataFrame to JSON
            output = json.loads(db_final_encoded.to_json(orient='records', date_format='iso'))
            return output

    except Exception as e:
        print(f"Retrieval of Tweet from hashtags failed : {e}")

# %%
tweet_id="1239696517008482300"
df=search_retweets(tweet_id)
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []
# Retrieval of Tweet from hashtags failed : "['_id', 'user_id_str'] not found in axis"

# %% [markdown]
# ### search_by_username

# %%
def search_by_user_name(user_name=None):
    try:
        cur.execute(f"""SELECT id_str,name,screen_name,verified,followers_count,friends_count FROM user_data WHERE (name LIKE '%{user_name}%') OR (screen_name LIKE '%{user_name}%')""")
        user_data=cur.fetchall()
        columns = [desc[0] for desc in cur.description]
        df = pd.DataFrame(user_data, columns=columns)
        db_final_encoded = df.map(handle_non_utf8)
            
            # Convert the DataFrame to JSON
        output = json.loads(db_final_encoded.to_json(orient='records', date_format='iso'))
        return output
    except Exception as e:
        print(f"Retrieval of Tweet from username failed : {e}")

# %%
search_by_user_name('Ben')
# Out:
# [{'id_str': '579373345',
#   'name': 'Jacob Bennett',
#   'screen_name': 'Red4Jacob',
#   'verified': 'False',
#   'followers_count': '142',
#   'friends_count': '333'},
#  {'id_str': '502796617',
#   'name': 'Bengt Höjer',
#   'screen_name': 'BengtHojer',
#   'verified': 'False',
#   'followers_count': '8061',
#   'friends_count': '5472'},
#  {'id_str': '2925375086',
#   'name': 'Benin',
#   'screen_name': 'Benin_offl',
#   'verified': 'False',
#   'followers_count': '1166',
#   'friends_count': '346'},
#  {'id_str': '3106609956',
#   'name': 'News18Bangla',
#   'screen_name': 'News18Bengali',
#   'verified': 'True',
#   'followers_count': '24666',
#   'friends_count': '298'},
#  {'id_str': '1210135033752756224',
#   'name': 'Hasan Muhammad',
#   'screen_name': 'HasanBenMuhammd',
#   'verified': 'False',
#   'followers_count': '590',
#   'friends_count': '1161'},
#  {'id_str': '1072867156046503936',
#   'name': 'TNIE Karnataka',
#   'screen_name': 'XpressBengaluru',
#   'verified': 'True',
#   'followers_count': '7536',
#   'friends_count': '85'},
#  {'id_str': '224816532',
#   'name': 'Bengt L.Digre',
#   'screen_name': 'Bhenth',
#   'verified': 'False',
#   'followers_count': '5077',
#   'friends_count': '5565'},
#  {'id_str': '1248262279252107267',
#   'name': 'Ben Mama',
#   'screen_name': 'BenMama8',
#   'verified': 'False',
#   'followers_count': '3',
#   'friends_count': '39'},
#  {'id_str': '1043923790810345472',
#   'name': 'BJPMM4Bengal',
#   'screen_name': 'BJPMM4Bengal',
#   'verified': 'False',
#   'followers_count': '3042',
#   'friends_count': '132'},
#  {'id_str': '1037659386171346945',
#   'name': "Ben's Immortel Officiel 💪🦅",
#   'screen_name': 'ElImmortel',
#   'verified': 'False',
#   'followers_count': '685',
#   'friends_count': '932'},
#  {'id_str': '1157384503989559297',
#   'name': 'Benjamin',
#   'screen_name': 'Benjami72055940',
#   'verified': 'False',
#   'followers_count': '130',
#   'friends_count': '333'},
#  {'id_str': '928863028384272384',
#   'name': 'Bonga Benya',
#   'screen_name': 'Billy_BensonSA',
#   'verified': 'False',
#   'followers_count': '2906',
#   'friends_count': '1587'},
#  {'id_str': '1248285771573977088',
#   'name': 'Benimmevzuminsan2',
#   'screen_name': 'insanlik06',
#   'verified': 'False',
#   'followers_count': '217',
#   'friends_count': '391'},
#  {'id_str': '879016855586918400',
#   'name': 'Kartuz Benno',
#   'screen_name': 'KartuzB',
#   'verified': 'False',
#   'followers_count': '350',
#   'friends_count': '321'},
#  {'id_str': '962146088852443137',
#   'name': 'Benvolio',
#   'screen_name': 'BenDelecto',
#   'verified': 'False',
#   'followers_count': '22',
#   'friends_count': '301'},
#  {'id_str': '1212515853284999168',
#   'name': 'Benard john',
#   'screen_name': 'Benardj37503641',
#   'verified': 'False',
#   'followers_count': '81',
#   'friends_count': '235'},
#  {'id_str': '556235898',
#   'name': 'Ben McKenna',
#   'screen_name': 'benmckennaJPI',
#   'verified': 'False',
#   'followers_count': '845',
#   'friends_count': '583'},
#  {'id_str': '47165852',
#   'name': 'Ben W!ers',
#   'screen_name': 'benwiers',
#   'verified': 'False',
#   'followers_count': '349',
#   'friends_count': '1162'},
#  {'id_str': '1182594091927965696',
#   'name': 'Ben Müslimlerdenim',
#   'screen_name': 'muslimlerdenim',
#   'verified': 'False',
#   'followers_count': '250',
#   'friends_count': '531'},
#  {'id_str': '14458227',
#   'name': 'Ben Woosley',
#   'screen_name': 'empact',
#   'verified': 'False',
#   'followers_count': '1101',
#   'friends_count': '2051'},
#  {'id_str': '811768215973990400',
#   'name': 'Bing my Bong',
#   'screen_name': 'Benmen148',
#   'verified': 'False',
#   'followers_count': '3',
#   'friends_count': '72'},
#  {'id_str': '1013204313026555908',
#   'name': 'Prof. Dr. Bengi BAŞER',
#   'screen_name': 'bengibaser',
#   'verified': 'False',
#   'followers_count': '20110',
#   'friends_count': '159'},
#  {'id_str': '929750901215993857',
#   'name': 'scooterd22',
#   'screen_name': 'ScottDiBenedet2',
#   'verified': 'False',
#   'followers_count': '92',
#   'friends_count': '164'},
#  {'id_str': '635067841',
#   'name': 'Carli Bene',
#   'screen_name': 'BandoBarbi',
#   'verified': 'False',
#   'followers_count': '526',
#   'friends_count': '957'},
#  {'id_str': '149864610',
#   'name': 'B. B. Singh-Ebinger',
#   'screen_name': 'BenjaminBhim',
#   'verified': 'False',
#   'followers_count': '121',
#   'friends_count': '859'},
#  {'id_str': '218653062',
#   'name': 'Thorsten Benner',
#   'screen_name': 'thorstenbenner',
#   'verified': 'True',
#   'followers_count': '11425',
#   'friends_count': '979'},
#  {'id_str': '1850333580',
#   'name': 'Ben Spielberg',
#   'screen_name': 'BenSpielberg',
#   'verified': 'True',
#   'followers_count': '16481',
#   'friends_count': '2477'},
#  {'id_str': '2231797674',
#   'name': 'Grumpy',
#   'screen_name': '_DBen_',
#   'verified': 'False',
#   'followers_count': '64',
#   'friends_count': '28'},
#  {'id_str': '793043434600820736',
#   'name': 'Russell Bentley',
#   'screen_name': 'russell_runner',
#   'verified': 'False',
#   'followers_count': '2858',
#   'friends_count': '1579'},
#  {'id_str': '25059149',
#   'name': 'Benjamin-Immanuel Hoff 🇪🇺 🚩✡️',
#   'screen_name': 'BenjaminHoff',
#   'verified': 'True',
#   'followers_count': '7492',
#   'friends_count': '1223'},
#  {'id_str': '971390700460937216',
#   'name': 'Camilla Benz',
#   'screen_name': 'camilla_benz',
#   'verified': 'False',
#   'followers_count': '6178',
#   'friends_count': '15'},
#  {'id_str': '1073356022922784768',
#   'name': 'Unser Corona-Pärchen♡',
#   'screen_name': 'Benosh6',
#   'verified': 'False',
#   'followers_count': '33',
#   'friends_count': '71'},
#  {'id_str': '1123554541478338561',
#   'name': 'Capitan John Benavides',
#   'screen_name': 'jhon_ejc',
#   'verified': 'False',
#   'followers_count': '147',
#   'friends_count': '90'},
#  {'id_str': '347368618',
#   'name': 'Matthew Bendure',
#   'screen_name': 'mattbendure',
#   'verified': 'False',
#   'followers_count': '10',
#   'friends_count': '163'},
#  {'id_str': '853722594742292481',
#   'name': 'Ben Schulz',
#   'screen_name': 'Ben0707Hamburg',
#   'verified': 'False',
#   'followers_count': '49',
#   'friends_count': '124'},
#  {'id_str': '1241560050872864769',
#   'name': 'JaxonBentley',
#   'screen_name': 'JCB_ADHD',
#   'verified': 'False',
#   'followers_count': '1',
#   'friends_count': '44'},
#  {'id_str': '386791423',
#   'name': 'BenchWarmers',
#   'screen_name': 'BeWarmers',
#   'verified': 'True',
#   'followers_count': '194003',
#   'friends_count': '190905'},
#  {'id_str': '2272927180',
#   'name': 'YKEE BENDA🌎',
#   'screen_name': 'YkeeBenda',
#   'verified': 'False',
#   'followers_count': '83856',
#   'friends_count': '68'},
#  {'id_str': '1838902352',
#   'name': 'Kent Hiroi (広井健人) @ 🏡',
#   'screen_name': 'KentoDaBento',
#   'verified': 'False',
#   'followers_count': '418',
#   'friends_count': '818'},
#  {'id_str': '3179176859',
#   'name': 'سمرمرمرمر🇸🇩',
#   'screen_name': 'SamarBengawi',
#   'verified': 'False',
#   'followers_count': '20926',
#   'friends_count': '789'},
#  {'id_str': '481531753',
#   'name': 'Benny Illinger',
#   'screen_name': 'IamIllgner',
#   'verified': 'False',
#   'followers_count': '1945',
#   'friends_count': '565'}]
